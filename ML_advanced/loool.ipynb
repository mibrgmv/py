# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 7.6 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 10.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import optuna
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# --- Data Loading ---
def load_cifar10_data(batch_size=128):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

    testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
    testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader

# --- Model Definition ---
class SimpleCNN(nn.Module):
    def __init__(self, num_conv_layers, num_filters_base, kernel_size, dropout_rate, num_fc_units):
        super(SimpleCNN, self).__init__()
        self.conv_layers = nn.ModuleList()
        in_channels = 3
        for i in range(num_conv_layers):
            out_channels = num_filters_base * (2**i)
            self.conv_layers.append(nn.Conv2d(in_channels, out_channels, kernel_size, padding=kernel_size//2))
            self.conv_layers.append(nn.ReLU())
            self.conv_layers.append(nn.MaxPool2d(2, 2))
            in_channels = out_channels

        self.dropout = nn.Dropout(dropout_rate)

        with torch.no_grad():
            dummy_input = torch.randn(1, 3, 32, 32)
            for layer in self.conv_layers:
                dummy_input = layer(dummy_input)
            fc_input_size = torch.flatten(dummy_input, 1).shape[1]

        self.fc1 = nn.Linear(fc_input_size, num_fc_units)
        self.fc2 = nn.Linear(num_fc_units, 10)

    def forward(self, x):
        for layer in self.conv_layers:
            x = layer(x)
        x = torch.flatten(x, 1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# --- Training and Evaluation ---
def train_model(model, train_loader, optimizer, criterion, num_epochs, device=None):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)
    all_losses = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        epoch_losses = []

        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            epoch_losses.append(loss.item())

            if i % 50 == 49:
                avg_loss = running_loss / 50
                print(f'Epoch [{epoch + 1}], Batch [{i + 1}], Loss: {avg_loss:.4f}')
                running_loss = 0.0

        avg_epoch_loss = np.mean(epoch_losses)
        all_losses.append(avg_epoch_loss)

    return all_losses

def evaluate_model(model, test_loader, device=None):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy:.2f}%')
    return accuracy

# --- Optuna Objective Function ---
def objective(trial):
    num_conv_layers = trial.suggest_int('num_conv_layers', 1, 3)
    num_filters_base = trial.suggest_categorical('num_filters_base', [16, 32, 64])
    kernel_size = trial.suggest_categorical('kernel_size', [3, 5])
    dropout_rate = trial.suggest_float('dropout_rate', 0.2, 0.6)
    num_fc_units = trial.suggest_categorical('num_fc_units', [128, 256, 512])
    learning_rate = trial.suggest_float('learning_rate', 5e-4, 5e-3, log=True)
    optimizer_type = trial.suggest_categorical('optimizer', ['Adam', 'SGD'])

    trainloader, testloader = load_cifar10_data()
    model = SimpleCNN(num_conv_layers, num_filters_base, kernel_size, dropout_rate, num_fc_units)
    criterion = nn.CrossEntropyLoss()

    if optimizer_type == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
    else:
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

    print(f'Starting trial {trial.number} with parameters: {trial.params}')
    epochs = 10
    losses = train_model(model, trainloader, optimizer, criterion, epochs)

    accuracy = evaluate_model(model, testloader)

    trial.set_user_attr("losses", losses)

    return accuracy

# --- Main Optimization Loop ---
if __name__ == '__main__':
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=20)

    print("Number of finished trials: {}".format(len(study.trials)))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: {}".format(trial.params))

    # --- Visualization of Loss ---
    plt.figure(figsize=(10, 6))
    for trial in study.trials:
        if trial.state == optuna.trial.TrialState.COMPLETE and "losses" in trial.user_attrs:
            epochs = range(1, len(trial.user_attrs["losses"]) + 1)
            plt.plot(epochs, trial.user_attrs["losses"], label=f'Trial {trial.number}')

    plt.title('Training Loss per Epoch for Different Trials')
    plt.xlabel('Epoch')
    plt.ylabel('Average Loss')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# [I 2025-04-30 18:59:50,725] A new study created in memory with name: no-name-2633aed2-4481-4514-a0d8-d5057cf00d37
# 100%|██████████| 170M/170M [00:03<00:00, 46.8MB/s]
# Starting trial 0 with parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5655399311106099, 'num_fc_units': 512, 'learning_rate': 0.0012826948575171688, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.2652
# Epoch [1], Batch [100], Loss: 2.1704
# Epoch [1], Batch [150], Loss: 2.0873
# Epoch [1], Batch [200], Loss: 2.0067
# Epoch [1], Batch [250], Loss: 1.9475
# Epoch [1], Batch [300], Loss: 1.9184
# Epoch [1], Batch [350], Loss: 1.8543
# Epoch [2], Batch [50], Loss: 1.8212
# Epoch [2], Batch [100], Loss: 1.7811
# Epoch [2], Batch [150], Loss: 1.7749
# Epoch [2], Batch [200], Loss: 1.7451
# Epoch [2], Batch [250], Loss: 1.7151
# Epoch [2], Batch [300], Loss: 1.6971
# Epoch [2], Batch [350], Loss: 1.6858
# Epoch [3], Batch [50], Loss: 1.6330
# Epoch [3], Batch [100], Loss: 1.6169
# Epoch [3], Batch [150], Loss: 1.6246
# Epoch [3], Batch [200], Loss: 1.5714
# Epoch [3], Batch [250], Loss: 1.5838
# Epoch [3], Batch [300], Loss: 1.5753
# Epoch [3], Batch [350], Loss: 1.5311
# Epoch [4], Batch [50], Loss: 1.5279
# Epoch [4], Batch [100], Loss: 1.5070
# Epoch [4], Batch [150], Loss: 1.4859
# Epoch [4], Batch [200], Loss: 1.4898
# Epoch [4], Batch [250], Loss: 1.4602
# Epoch [4], Batch [300], Loss: 1.4528
# Epoch [4], Batch [350], Loss: 1.4222
# Epoch [5], Batch [50], Loss: 1.4168
# Epoch [5], Batch [100], Loss: 1.3935
# Epoch [5], Batch [150], Loss: 1.4083
# Epoch [5], Batch [200], Loss: 1.4110
# Epoch [5], Batch [250], Loss: 1.3987
# Epoch [5], Batch [300], Loss: 1.3754
# Epoch [5], Batch [350], Loss: 1.3875
# Epoch [6], Batch [50], Loss: 1.3554
# Epoch [6], Batch [100], Loss: 1.3584
# Epoch [6], Batch [150], Loss: 1.3481
# Epoch [6], Batch [200], Loss: 1.3233
# Epoch [6], Batch [250], Loss: 1.3464
# Epoch [6], Batch [300], Loss: 1.3062
# Epoch [6], Batch [350], Loss: 1.3220
# Epoch [7], Batch [50], Loss: 1.2962
# Epoch [7], Batch [100], Loss: 1.3112
# Epoch [7], Batch [150], Loss: 1.2994
# Epoch [7], Batch [200], Loss: 1.3081
# Epoch [7], Batch [250], Loss: 1.2885
# Epoch [7], Batch [300], Loss: 1.2776
# Epoch [7], Batch [350], Loss: 1.2490
# Epoch [8], Batch [50], Loss: 1.2716
# Epoch [8], Batch [100], Loss: 1.2705
# Epoch [8], Batch [150], Loss: 1.2400
# Epoch [8], Batch [200], Loss: 1.2358
# Epoch [8], Batch [250], Loss: 1.2649
# Epoch [8], Batch [300], Loss: 1.2470
# Epoch [8], Batch [350], Loss: 1.2425
# Epoch [9], Batch [50], Loss: 1.2200
# Epoch [9], Batch [100], Loss: 1.2163
# Epoch [9], Batch [150], Loss: 1.2228
# Epoch [9], Batch [200], Loss: 1.2282
# Epoch [9], Batch [250], Loss: 1.2211
# Epoch [9], Batch [300], Loss: 1.2094
# Epoch [9], Batch [350], Loss: 1.2203
# Epoch [10], Batch [50], Loss: 1.1960
# Epoch [10], Batch [100], Loss: 1.2034
# Epoch [10], Batch [150], Loss: 1.1975
# Epoch [10], Batch [200], Loss: 1.1802
# Epoch [10], Batch [250], Loss: 1.1781
# Epoch [10], Batch [300], Loss: 1.1762
# Epoch [10], Batch [350], Loss: 1.1947
# [I 2025-04-30 19:02:01,029] Trial 0 finished with value: 59.16 and parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5655399311106099, 'num_fc_units': 512, 'learning_rate': 0.0012826948575171688, 'optimizer': 'SGD'}. Best is trial 0 with value: 59.16.
# Test Accuracy: 59.16%
# Starting trial 1 with parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5358669717901521, 'num_fc_units': 256, 'learning_rate': 0.0006837330194076963, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.3029
# Epoch [1], Batch [100], Loss: 2.3040
# Epoch [1], Batch [150], Loss: 2.3031
# Epoch [1], Batch [200], Loss: 2.3015
# Epoch [1], Batch [250], Loss: 2.3008
# Epoch [1], Batch [300], Loss: 2.3005
# Epoch [1], Batch [350], Loss: 2.2998
# Epoch [2], Batch [50], Loss: 2.2986
# Epoch [2], Batch [100], Loss: 2.2967
# Epoch [2], Batch [150], Loss: 2.2954
# Epoch [2], Batch [200], Loss: 2.2951
# Epoch [2], Batch [250], Loss: 2.2935
# Epoch [2], Batch [300], Loss: 2.2911
# Epoch [2], Batch [350], Loss: 2.2903
# Epoch [3], Batch [50], Loss: 2.2852
# Epoch [3], Batch [100], Loss: 2.2824
# Epoch [3], Batch [150], Loss: 2.2779
# Epoch [3], Batch [200], Loss: 2.2737
# Epoch [3], Batch [250], Loss: 2.2667
# Epoch [3], Batch [300], Loss: 2.2613
# Epoch [3], Batch [350], Loss: 2.2507
# Epoch [4], Batch [50], Loss: 2.2307
# Epoch [4], Batch [100], Loss: 2.2119
# Epoch [4], Batch [150], Loss: 2.1898
# Epoch [4], Batch [200], Loss: 2.1641
# Epoch [4], Batch [250], Loss: 2.1455
# Epoch [4], Batch [300], Loss: 2.1302
# Epoch [4], Batch [350], Loss: 2.1139
# Epoch [5], Batch [50], Loss: 2.0833
# Epoch [5], Batch [100], Loss: 2.0690
# Epoch [5], Batch [150], Loss: 2.0647
# Epoch [5], Batch [200], Loss: 2.0449
# Epoch [5], Batch [250], Loss: 2.0252
# Epoch [5], Batch [300], Loss: 2.0165
# Epoch [5], Batch [350], Loss: 2.0010
# Epoch [6], Batch [50], Loss: 1.9839
# Epoch [6], Batch [100], Loss: 1.9860
# Epoch [6], Batch [150], Loss: 1.9487
# Epoch [6], Batch [200], Loss: 1.9370
# Epoch [6], Batch [250], Loss: 1.9386
# Epoch [6], Batch [300], Loss: 1.9384
# Epoch [6], Batch [350], Loss: 1.9208
# Epoch [7], Batch [50], Loss: 1.8992
# Epoch [7], Batch [100], Loss: 1.8901
# Epoch [7], Batch [150], Loss: 1.8923
# Epoch [7], Batch [200], Loss: 1.8878
# Epoch [7], Batch [250], Loss: 1.8682
# Epoch [7], Batch [300], Loss: 1.8539
# Epoch [7], Batch [350], Loss: 1.8451
# Epoch [8], Batch [50], Loss: 1.8402
# Epoch [8], Batch [100], Loss: 1.8394
# Epoch [8], Batch [150], Loss: 1.8032
# Epoch [8], Batch [200], Loss: 1.8021
# Epoch [8], Batch [250], Loss: 1.7881
# Epoch [8], Batch [300], Loss: 1.7920
# Epoch [8], Batch [350], Loss: 1.7618
# Epoch [9], Batch [50], Loss: 1.7744
# Epoch [9], Batch [100], Loss: 1.7468
# Epoch [9], Batch [150], Loss: 1.7678
# Epoch [9], Batch [200], Loss: 1.7168
# Epoch [9], Batch [250], Loss: 1.7273
# Epoch [9], Batch [300], Loss: 1.7371
# Epoch [9], Batch [350], Loss: 1.7403
# Epoch [10], Batch [50], Loss: 1.7148
# Epoch [10], Batch [100], Loss: 1.6862
# Epoch [10], Batch [150], Loss: 1.6785
# Epoch [10], Batch [200], Loss: 1.7009
# Epoch [10], Batch [250], Loss: 1.6891
# Epoch [10], Batch [300], Loss: 1.6570
# Epoch [10], Batch [350], Loss: 1.6806
# [I 2025-04-30 19:04:05,886] Trial 1 finished with value: 42.73 and parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5358669717901521, 'num_fc_units': 256, 'learning_rate': 0.0006837330194076963, 'optimizer': 'SGD'}. Best is trial 0 with value: 59.16.
# Test Accuracy: 42.73%
# Starting trial 2 with parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.43626372512403055, 'num_fc_units': 256, 'learning_rate': 0.004760653359404253, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.1842
# Epoch [1], Batch [100], Loss: 1.9531
# Epoch [1], Batch [150], Loss: 1.8311
# Epoch [1], Batch [200], Loss: 1.7463
# Epoch [1], Batch [250], Loss: 1.6672
# Epoch [1], Batch [300], Loss: 1.6053
# Epoch [1], Batch [350], Loss: 1.5609
# Epoch [2], Batch [50], Loss: 1.4812
# Epoch [2], Batch [100], Loss: 1.4294
# Epoch [2], Batch [150], Loss: 1.4395
# Epoch [2], Batch [200], Loss: 1.4041
# Epoch [2], Batch [250], Loss: 1.3775
# Epoch [2], Batch [300], Loss: 1.3666
# Epoch [2], Batch [350], Loss: 1.3568
# Epoch [3], Batch [50], Loss: 1.3176
# Epoch [3], Batch [100], Loss: 1.2907
# Epoch [3], Batch [150], Loss: 1.2788
# Epoch [3], Batch [200], Loss: 1.2425
# Epoch [3], Batch [250], Loss: 1.2458
# Epoch [3], Batch [300], Loss: 1.2527
# Epoch [3], Batch [350], Loss: 1.2523
# Epoch [4], Batch [50], Loss: 1.1809
# Epoch [4], Batch [100], Loss: 1.1907
# Epoch [4], Batch [150], Loss: 1.1677
# Epoch [4], Batch [200], Loss: 1.1598
# Epoch [4], Batch [250], Loss: 1.1548
# Epoch [4], Batch [300], Loss: 1.1652
# Epoch [4], Batch [350], Loss: 1.1405
# Epoch [5], Batch [50], Loss: 1.0883
# Epoch [5], Batch [100], Loss: 1.0771
# Epoch [5], Batch [150], Loss: 1.0917
# Epoch [5], Batch [200], Loss: 1.0847
# Epoch [5], Batch [250], Loss: 1.0645
# Epoch [5], Batch [300], Loss: 1.0819
# Epoch [5], Batch [350], Loss: 1.0645
# Epoch [6], Batch [50], Loss: 1.0212
# Epoch [6], Batch [100], Loss: 1.0167
# Epoch [6], Batch [150], Loss: 1.0133
# Epoch [6], Batch [200], Loss: 1.0288
# Epoch [6], Batch [250], Loss: 1.0177
# Epoch [6], Batch [300], Loss: 0.9992
# Epoch [6], Batch [350], Loss: 0.9996
# Epoch [7], Batch [50], Loss: 0.9430
# Epoch [7], Batch [100], Loss: 0.9547
# Epoch [7], Batch [150], Loss: 0.9771
# Epoch [7], Batch [200], Loss: 0.9370
# Epoch [7], Batch [250], Loss: 0.9467
# Epoch [7], Batch [300], Loss: 0.9422
# Epoch [7], Batch [350], Loss: 0.9524
# Epoch [8], Batch [50], Loss: 0.8953
# Epoch [8], Batch [100], Loss: 0.8902
# Epoch [8], Batch [150], Loss: 0.8932
# Epoch [8], Batch [200], Loss: 0.8999
# Epoch [8], Batch [250], Loss: 0.9025
# Epoch [8], Batch [300], Loss: 0.9006
# Epoch [8], Batch [350], Loss: 0.8923
# Epoch [9], Batch [50], Loss: 0.8444
# Epoch [9], Batch [100], Loss: 0.8598
# Epoch [9], Batch [150], Loss: 0.8737
# Epoch [9], Batch [200], Loss: 0.8481
# Epoch [9], Batch [250], Loss: 0.8680
# Epoch [9], Batch [300], Loss: 0.8561
# Epoch [9], Batch [350], Loss: 0.8538
# Epoch [10], Batch [50], Loss: 0.7606
# Epoch [10], Batch [100], Loss: 0.8027
# Epoch [10], Batch [150], Loss: 0.8039
# Epoch [10], Batch [200], Loss: 0.8162
# Epoch [10], Batch [250], Loss: 0.8115
# Epoch [10], Batch [300], Loss: 0.8257
# Epoch [10], Batch [350], Loss: 0.8008
# [I 2025-04-30 19:06:10,869] Trial 2 finished with value: 68.52 and parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.43626372512403055, 'num_fc_units': 256, 'learning_rate': 0.004760653359404253, 'optimizer': 'SGD'}. Best is trial 2 with value: 68.52.
# Test Accuracy: 68.52%
# Starting trial 3 with parameters: {'num_conv_layers': 2, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.5991859215725857, 'num_fc_units': 128, 'learning_rate': 0.0006306195808926453, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.3029
# Epoch [1], Batch [100], Loss: 2.2982
# Epoch [1], Batch [150], Loss: 2.2960
# Epoch [1], Batch [200], Loss: 2.2899
# Epoch [1], Batch [250], Loss: 2.2828
# Epoch [1], Batch [300], Loss: 2.2754
# Epoch [1], Batch [350], Loss: 2.2638
# Epoch [2], Batch [50], Loss: 2.2388
# Epoch [2], Batch [100], Loss: 2.2144
# Epoch [2], Batch [150], Loss: 2.1913
# Epoch [2], Batch [200], Loss: 2.1672
# Epoch [2], Batch [250], Loss: 2.1576
# Epoch [2], Batch [300], Loss: 2.1345
# Epoch [2], Batch [350], Loss: 2.1045
# Epoch [3], Batch [50], Loss: 2.0546
# Epoch [3], Batch [100], Loss: 2.0424
# Epoch [3], Batch [150], Loss: 2.0277
# Epoch [3], Batch [200], Loss: 2.0017
# Epoch [3], Batch [250], Loss: 1.9946
# Epoch [3], Batch [300], Loss: 1.9807
# Epoch [3], Batch [350], Loss: 1.9665
# Epoch [4], Batch [50], Loss: 1.9522
# Epoch [4], Batch [100], Loss: 1.9345
# Epoch [4], Batch [150], Loss: 1.9283
# Epoch [4], Batch [200], Loss: 1.9053
# Epoch [4], Batch [250], Loss: 1.8921
# Epoch [4], Batch [300], Loss: 1.8749
# Epoch [4], Batch [350], Loss: 1.8801
# Epoch [5], Batch [50], Loss: 1.8551
# Epoch [5], Batch [100], Loss: 1.8503
# Epoch [5], Batch [150], Loss: 1.8457
# Epoch [5], Batch [200], Loss: 1.8251
# Epoch [5], Batch [250], Loss: 1.8158
# Epoch [5], Batch [300], Loss: 1.8039
# Epoch [5], Batch [350], Loss: 1.7918
# Epoch [6], Batch [50], Loss: 1.7894
# Epoch [6], Batch [100], Loss: 1.7712
# Epoch [6], Batch [150], Loss: 1.7622
# Epoch [6], Batch [200], Loss: 1.7400
# Epoch [6], Batch [250], Loss: 1.7440
# Epoch [6], Batch [300], Loss: 1.7290
# Epoch [6], Batch [350], Loss: 1.7496
# Epoch [7], Batch [50], Loss: 1.7232
# Epoch [7], Batch [100], Loss: 1.7023
# Epoch [7], Batch [150], Loss: 1.7264
# Epoch [7], Batch [200], Loss: 1.6917
# Epoch [7], Batch [250], Loss: 1.6882
# Epoch [7], Batch [300], Loss: 1.6610
# Epoch [7], Batch [350], Loss: 1.6775
# Epoch [8], Batch [50], Loss: 1.6724
# Epoch [8], Batch [100], Loss: 1.6570
# Epoch [8], Batch [150], Loss: 1.6355
# Epoch [8], Batch [200], Loss: 1.6440
# Epoch [8], Batch [250], Loss: 1.6430
# Epoch [8], Batch [300], Loss: 1.6522
# Epoch [8], Batch [350], Loss: 1.6348
# Epoch [9], Batch [50], Loss: 1.6440
# Epoch [9], Batch [100], Loss: 1.6159
# Epoch [9], Batch [150], Loss: 1.6248
# Epoch [9], Batch [200], Loss: 1.6080
# Epoch [9], Batch [250], Loss: 1.5869
# Epoch [9], Batch [300], Loss: 1.5970
# Epoch [9], Batch [350], Loss: 1.5882
# Epoch [10], Batch [50], Loss: 1.5888
# Epoch [10], Batch [100], Loss: 1.5902
# Epoch [10], Batch [150], Loss: 1.5716
# Epoch [10], Batch [200], Loss: 1.5589
# Epoch [10], Batch [250], Loss: 1.5772
# Epoch [10], Batch [300], Loss: 1.5733
# Epoch [10], Batch [350], Loss: 1.5756
# [I 2025-04-30 19:08:18,565] Trial 3 finished with value: 46.76 and parameters: {'num_conv_layers': 2, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.5991859215725857, 'num_fc_units': 128, 'learning_rate': 0.0006306195808926453, 'optimizer': 'SGD'}. Best is trial 2 with value: 68.52.
# Test Accuracy: 46.76%
# Starting trial 4 with parameters: {'num_conv_layers': 2, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.25603767364167623, 'num_fc_units': 128, 'learning_rate': 0.00358200741153407, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.2955
# Epoch [1], Batch [100], Loss: 2.2320
# Epoch [1], Batch [150], Loss: 2.0944
# Epoch [1], Batch [200], Loss: 2.0037
# Epoch [1], Batch [250], Loss: 1.9007
# Epoch [1], Batch [300], Loss: 1.8810
# Epoch [1], Batch [350], Loss: 1.8068
# Epoch [2], Batch [50], Loss: 1.6964
# Epoch [2], Batch [100], Loss: 1.6558
# Epoch [2], Batch [150], Loss: 1.6088
# Epoch [2], Batch [200], Loss: 1.5724
# Epoch [2], Batch [250], Loss: 1.5316
# Epoch [2], Batch [300], Loss: 1.5185
# Epoch [2], Batch [350], Loss: 1.4615
# Epoch [3], Batch [50], Loss: 1.4289
# Epoch [3], Batch [100], Loss: 1.4288
# Epoch [3], Batch [150], Loss: 1.4123
# Epoch [3], Batch [200], Loss: 1.4260
# Epoch [3], Batch [250], Loss: 1.3947
# Epoch [3], Batch [300], Loss: 1.3698
# Epoch [3], Batch [350], Loss: 1.3652
# Epoch [4], Batch [50], Loss: 1.3305
# Epoch [4], Batch [100], Loss: 1.3204
# Epoch [4], Batch [150], Loss: 1.3178
# Epoch [4], Batch [200], Loss: 1.3050
# Epoch [4], Batch [250], Loss: 1.3038
# Epoch [4], Batch [300], Loss: 1.2748
# Epoch [4], Batch [350], Loss: 1.2754
# Epoch [5], Batch [50], Loss: 1.2539
# Epoch [5], Batch [100], Loss: 1.2299
# Epoch [5], Batch [150], Loss: 1.2262
# Epoch [5], Batch [200], Loss: 1.2191
# Epoch [5], Batch [250], Loss: 1.1917
# Epoch [5], Batch [300], Loss: 1.2019
# Epoch [5], Batch [350], Loss: 1.2141
# Epoch [6], Batch [50], Loss: 1.1505
# Epoch [6], Batch [100], Loss: 1.1531
# Epoch [6], Batch [150], Loss: 1.1563
# Epoch [6], Batch [200], Loss: 1.1260
# Epoch [6], Batch [250], Loss: 1.1444
# Epoch [6], Batch [300], Loss: 1.1494
# Epoch [6], Batch [350], Loss: 1.1400
# Epoch [7], Batch [50], Loss: 1.0730
# Epoch [7], Batch [100], Loss: 1.1129
# Epoch [7], Batch [150], Loss: 1.0706
# Epoch [7], Batch [200], Loss: 1.0966
# Epoch [7], Batch [250], Loss: 1.0770
# Epoch [7], Batch [300], Loss: 1.0668
# Epoch [7], Batch [350], Loss: 1.0777
# Epoch [8], Batch [50], Loss: 1.0471
# Epoch [8], Batch [100], Loss: 1.0280
# Epoch [8], Batch [150], Loss: 1.0529
# Epoch [8], Batch [200], Loss: 1.0261
# Epoch [8], Batch [250], Loss: 0.9983
# Epoch [8], Batch [300], Loss: 0.9992
# Epoch [8], Batch [350], Loss: 1.0261
# Epoch [9], Batch [50], Loss: 0.9610
# Epoch [9], Batch [100], Loss: 0.9729
# Epoch [9], Batch [150], Loss: 0.9992
# Epoch [9], Batch [200], Loss: 0.9790
# Epoch [9], Batch [250], Loss: 0.9785
# Epoch [9], Batch [300], Loss: 0.9724
# Epoch [9], Batch [350], Loss: 0.9834
# Epoch [10], Batch [50], Loss: 0.9338
# Epoch [10], Batch [100], Loss: 0.9402
# Epoch [10], Batch [150], Loss: 0.9380
# Epoch [10], Batch [200], Loss: 0.9167
# Epoch [10], Batch [250], Loss: 0.9245
# Epoch [10], Batch [300], Loss: 0.9234
# Epoch [10], Batch [350], Loss: 0.9176
# [I 2025-04-30 19:10:26,035] Trial 4 finished with value: 66.42 and parameters: {'num_conv_layers': 2, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.25603767364167623, 'num_fc_units': 128, 'learning_rate': 0.00358200741153407, 'optimizer': 'SGD'}. Best is trial 2 with value: 68.52.
# Test Accuracy: 66.42%
# Starting trial 5 with parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.5991496636717633, 'num_fc_units': 128, 'learning_rate': 0.004119995770182085, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.2629
# Epoch [1], Batch [100], Loss: 2.1258
# Epoch [1], Batch [150], Loss: 1.9951
# Epoch [1], Batch [200], Loss: 1.9165
# Epoch [1], Batch [250], Loss: 1.8134
# Epoch [1], Batch [300], Loss: 1.7618
# Epoch [1], Batch [350], Loss: 1.7103
# Epoch [2], Batch [50], Loss: 1.6066
# Epoch [2], Batch [100], Loss: 1.6214
# Epoch [2], Batch [150], Loss: 1.5841
# Epoch [2], Batch [200], Loss: 1.5560
# Epoch [2], Batch [250], Loss: 1.5180
# Epoch [2], Batch [300], Loss: 1.5248
# Epoch [2], Batch [350], Loss: 1.5124
# Epoch [3], Batch [50], Loss: 1.4755
# Epoch [3], Batch [100], Loss: 1.4315
# Epoch [3], Batch [150], Loss: 1.4276
# Epoch [3], Batch [200], Loss: 1.4393
# Epoch [3], Batch [250], Loss: 1.4099
# Epoch [3], Batch [300], Loss: 1.3953
# Epoch [3], Batch [350], Loss: 1.3556
# Epoch [4], Batch [50], Loss: 1.3433
# Epoch [4], Batch [100], Loss: 1.3275
# Epoch [4], Batch [150], Loss: 1.3181
# Epoch [4], Batch [200], Loss: 1.2837
# Epoch [4], Batch [250], Loss: 1.2944
# Epoch [4], Batch [300], Loss: 1.3054
# Epoch [4], Batch [350], Loss: 1.2801
# Epoch [5], Batch [50], Loss: 1.2386
# Epoch [5], Batch [100], Loss: 1.2030
# Epoch [5], Batch [150], Loss: 1.2274
# Epoch [5], Batch [200], Loss: 1.2314
# Epoch [5], Batch [250], Loss: 1.2132
# Epoch [5], Batch [300], Loss: 1.1855
# Epoch [5], Batch [350], Loss: 1.1780
# Epoch [6], Batch [50], Loss: 1.1512
# Epoch [6], Batch [100], Loss: 1.1238
# Epoch [6], Batch [150], Loss: 1.1345
# Epoch [6], Batch [200], Loss: 1.1305
# Epoch [6], Batch [250], Loss: 1.1217
# Epoch [6], Batch [300], Loss: 1.1186
# Epoch [6], Batch [350], Loss: 1.1249
# Epoch [7], Batch [50], Loss: 1.0537
# Epoch [7], Batch [100], Loss: 1.0799
# Epoch [7], Batch [150], Loss: 1.0584
# Epoch [7], Batch [200], Loss: 1.0678
# Epoch [7], Batch [250], Loss: 1.0567
# Epoch [7], Batch [300], Loss: 1.0582
# Epoch [7], Batch [350], Loss: 1.0303
# Epoch [8], Batch [50], Loss: 1.0035
# Epoch [8], Batch [100], Loss: 1.0199
# Epoch [8], Batch [150], Loss: 1.0017
# Epoch [8], Batch [200], Loss: 1.0015
# Epoch [8], Batch [250], Loss: 1.0172
# Epoch [8], Batch [300], Loss: 0.9814
# Epoch [8], Batch [350], Loss: 1.0120
# Epoch [9], Batch [50], Loss: 0.9395
# Epoch [9], Batch [100], Loss: 0.9554
# Epoch [9], Batch [150], Loss: 0.9613
# Epoch [9], Batch [200], Loss: 0.9625
# Epoch [9], Batch [250], Loss: 0.9542
# Epoch [9], Batch [300], Loss: 0.9279
# Epoch [9], Batch [350], Loss: 0.9379
# Epoch [10], Batch [50], Loss: 0.9203
# Epoch [10], Batch [100], Loss: 0.9028
# Epoch [10], Batch [150], Loss: 0.9002
# Epoch [10], Batch [200], Loss: 0.9139
# Epoch [10], Batch [250], Loss: 0.9008
# Epoch [10], Batch [300], Loss: 0.9001
# Epoch [10], Batch [350], Loss: 0.8874
# [I 2025-04-30 19:12:38,901] Trial 5 finished with value: 70.22 and parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.5991496636717633, 'num_fc_units': 128, 'learning_rate': 0.004119995770182085, 'optimizer': 'SGD'}. Best is trial 5 with value: 70.22.
# Test Accuracy: 70.22%
# Starting trial 6 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3916632883700204, 'num_fc_units': 512, 'learning_rate': 0.0009184313761418757, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9473
# Epoch [1], Batch [100], Loss: 1.6290
# Epoch [1], Batch [150], Loss: 1.4695
# Epoch [1], Batch [200], Loss: 1.3744
# Epoch [1], Batch [250], Loss: 1.2909
# Epoch [1], Batch [300], Loss: 1.2365
# Epoch [1], Batch [350], Loss: 1.1937
# Epoch [2], Batch [50], Loss: 1.0906
# Epoch [2], Batch [100], Loss: 1.0357
# Epoch [2], Batch [150], Loss: 1.0170
# Epoch [2], Batch [200], Loss: 0.9623
# Epoch [2], Batch [250], Loss: 0.9518
# Epoch [2], Batch [300], Loss: 0.9334
# Epoch [2], Batch [350], Loss: 0.9444
# Epoch [3], Batch [50], Loss: 0.8078
# Epoch [3], Batch [100], Loss: 0.8009
# Epoch [3], Batch [150], Loss: 0.7893
# Epoch [3], Batch [200], Loss: 0.8091
# Epoch [3], Batch [250], Loss: 0.7865
# Epoch [3], Batch [300], Loss: 0.7704
# Epoch [3], Batch [350], Loss: 0.7766
# Epoch [4], Batch [50], Loss: 0.6733
# Epoch [4], Batch [100], Loss: 0.6571
# Epoch [4], Batch [150], Loss: 0.6607
# Epoch [4], Batch [200], Loss: 0.6652
# Epoch [4], Batch [250], Loss: 0.6593
# Epoch [4], Batch [300], Loss: 0.6516
# Epoch [4], Batch [350], Loss: 0.6683
# Epoch [5], Batch [50], Loss: 0.5470
# Epoch [5], Batch [100], Loss: 0.5419
# Epoch [5], Batch [150], Loss: 0.5581
# Epoch [5], Batch [200], Loss: 0.5440
# Epoch [5], Batch [250], Loss: 0.5609
# Epoch [5], Batch [300], Loss: 0.5538
# Epoch [5], Batch [350], Loss: 0.5775
# Epoch [6], Batch [50], Loss: 0.4442
# Epoch [6], Batch [100], Loss: 0.4534
# Epoch [6], Batch [150], Loss: 0.4560
# Epoch [6], Batch [200], Loss: 0.4606
# Epoch [6], Batch [250], Loss: 0.4749
# Epoch [6], Batch [300], Loss: 0.4683
# Epoch [6], Batch [350], Loss: 0.4699
# Epoch [7], Batch [50], Loss: 0.3694
# Epoch [7], Batch [100], Loss: 0.3707
# Epoch [7], Batch [150], Loss: 0.3750
# Epoch [7], Batch [200], Loss: 0.3823
# Epoch [7], Batch [250], Loss: 0.3860
# Epoch [7], Batch [300], Loss: 0.3904
# Epoch [7], Batch [350], Loss: 0.4077
# Epoch [8], Batch [50], Loss: 0.2961
# Epoch [8], Batch [100], Loss: 0.3048
# Epoch [8], Batch [150], Loss: 0.3122
# Epoch [8], Batch [200], Loss: 0.3153
# Epoch [8], Batch [250], Loss: 0.3266
# Epoch [8], Batch [300], Loss: 0.3436
# Epoch [8], Batch [350], Loss: 0.3456
# Epoch [9], Batch [50], Loss: 0.2279
# Epoch [9], Batch [100], Loss: 0.2188
# Epoch [9], Batch [150], Loss: 0.2640
# Epoch [9], Batch [200], Loss: 0.2409
# Epoch [9], Batch [250], Loss: 0.2858
# Epoch [9], Batch [300], Loss: 0.2832
# Epoch [9], Batch [350], Loss: 0.3104
# Epoch [10], Batch [50], Loss: 0.1991
# Epoch [10], Batch [100], Loss: 0.1992
# Epoch [10], Batch [150], Loss: 0.2081
# Epoch [10], Batch [200], Loss: 0.2377
# Epoch [10], Batch [250], Loss: 0.2373
# Epoch [10], Batch [300], Loss: 0.2337
# Epoch [10], Batch [350], Loss: 0.2499
# [I 2025-04-30 19:14:53,046] Trial 6 finished with value: 78.76 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3916632883700204, 'num_fc_units': 512, 'learning_rate': 0.0009184313761418757, 'optimizer': 'Adam'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 78.76%
# Starting trial 7 with parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.36783130800190234, 'num_fc_units': 256, 'learning_rate': 0.0010762877266502836, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.3027
# Epoch [1], Batch [100], Loss: 2.3007
# Epoch [1], Batch [150], Loss: 2.2996
# Epoch [1], Batch [200], Loss: 2.2958
# Epoch [1], Batch [250], Loss: 2.2942
# Epoch [1], Batch [300], Loss: 2.2902
# Epoch [1], Batch [350], Loss: 2.2846
# Epoch [2], Batch [50], Loss: 2.2588
# Epoch [2], Batch [100], Loss: 2.2241
# Epoch [2], Batch [150], Loss: 2.1600
# Epoch [2], Batch [200], Loss: 2.0913
# Epoch [2], Batch [250], Loss: 2.0374
# Epoch [2], Batch [300], Loss: 2.0205
# Epoch [2], Batch [350], Loss: 1.9976
# Epoch [3], Batch [50], Loss: 1.9381
# Epoch [3], Batch [100], Loss: 1.9278
# Epoch [3], Batch [150], Loss: 1.8922
# Epoch [3], Batch [200], Loss: 1.8878
# Epoch [3], Batch [250], Loss: 1.8653
# Epoch [3], Batch [300], Loss: 1.8395
# Epoch [3], Batch [350], Loss: 1.8066
# Epoch [4], Batch [50], Loss: 1.7620
# Epoch [4], Batch [100], Loss: 1.7671
# Epoch [4], Batch [150], Loss: 1.7397
# Epoch [4], Batch [200], Loss: 1.7304
# Epoch [4], Batch [250], Loss: 1.7016
# Epoch [4], Batch [300], Loss: 1.6865
# Epoch [4], Batch [350], Loss: 1.7080
# Epoch [5], Batch [50], Loss: 1.6453
# Epoch [5], Batch [100], Loss: 1.6293
# Epoch [5], Batch [150], Loss: 1.6381
# Epoch [5], Batch [200], Loss: 1.6115
# Epoch [5], Batch [250], Loss: 1.5976
# Epoch [5], Batch [300], Loss: 1.6099
# Epoch [5], Batch [350], Loss: 1.5829
# Epoch [6], Batch [50], Loss: 1.5669
# Epoch [6], Batch [100], Loss: 1.5693
# Epoch [6], Batch [150], Loss: 1.5670
# Epoch [6], Batch [200], Loss: 1.5308
# Epoch [6], Batch [250], Loss: 1.5233
# Epoch [6], Batch [300], Loss: 1.5198
# Epoch [6], Batch [350], Loss: 1.5229
# Epoch [7], Batch [50], Loss: 1.5086
# Epoch [7], Batch [100], Loss: 1.4790
# Epoch [7], Batch [150], Loss: 1.4638
# Epoch [7], Batch [200], Loss: 1.4839
# Epoch [7], Batch [250], Loss: 1.4724
# Epoch [7], Batch [300], Loss: 1.4748
# Epoch [7], Batch [350], Loss: 1.4590
# Epoch [8], Batch [50], Loss: 1.4479
# Epoch [8], Batch [100], Loss: 1.4398
# Epoch [8], Batch [150], Loss: 1.4023
# Epoch [8], Batch [200], Loss: 1.4415
# Epoch [8], Batch [250], Loss: 1.4029
# Epoch [8], Batch [300], Loss: 1.4264
# Epoch [8], Batch [350], Loss: 1.3909
# Epoch [9], Batch [50], Loss: 1.3995
# Epoch [9], Batch [100], Loss: 1.3787
# Epoch [9], Batch [150], Loss: 1.3966
# Epoch [9], Batch [200], Loss: 1.3991
# Epoch [9], Batch [250], Loss: 1.3721
# Epoch [9], Batch [300], Loss: 1.3635
# Epoch [9], Batch [350], Loss: 1.3619
# Epoch [10], Batch [50], Loss: 1.3507
# Epoch [10], Batch [100], Loss: 1.3548
# Epoch [10], Batch [150], Loss: 1.3395
# Epoch [10], Batch [200], Loss: 1.3321
# Epoch [10], Batch [250], Loss: 1.3042
# Epoch [10], Batch [300], Loss: 1.3561
# Epoch [10], Batch [350], Loss: 1.3292
# [I 2025-04-30 19:17:04,975] Trial 7 finished with value: 53.53 and parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.36783130800190234, 'num_fc_units': 256, 'learning_rate': 0.0010762877266502836, 'optimizer': 'SGD'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 53.53%
# Starting trial 8 with parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5223425157847674, 'num_fc_units': 256, 'learning_rate': 0.0005816501334749713, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.2893
# Epoch [1], Batch [100], Loss: 2.2518
# Epoch [1], Batch [150], Loss: 2.2101
# Epoch [1], Batch [200], Loss: 2.1696
# Epoch [1], Batch [250], Loss: 2.1457
# Epoch [1], Batch [300], Loss: 2.1113
# Epoch [1], Batch [350], Loss: 2.0773
# Epoch [2], Batch [50], Loss: 2.0358
# Epoch [2], Batch [100], Loss: 2.0275
# Epoch [2], Batch [150], Loss: 1.9926
# Epoch [2], Batch [200], Loss: 1.9760
# Epoch [2], Batch [250], Loss: 1.9515
# Epoch [2], Batch [300], Loss: 1.9290
# Epoch [2], Batch [350], Loss: 1.9237
# Epoch [3], Batch [50], Loss: 1.8890
# Epoch [3], Batch [100], Loss: 1.8819
# Epoch [3], Batch [150], Loss: 1.8763
# Epoch [3], Batch [200], Loss: 1.8643
# Epoch [3], Batch [250], Loss: 1.8474
# Epoch [3], Batch [300], Loss: 1.8333
# Epoch [3], Batch [350], Loss: 1.8376
# Epoch [4], Batch [50], Loss: 1.8075
# Epoch [4], Batch [100], Loss: 1.8145
# Epoch [4], Batch [150], Loss: 1.7879
# Epoch [4], Batch [200], Loss: 1.8024
# Epoch [4], Batch [250], Loss: 1.7763
# Epoch [4], Batch [300], Loss: 1.7701
# Epoch [4], Batch [350], Loss: 1.7612
# Epoch [5], Batch [50], Loss: 1.7493
# Epoch [5], Batch [100], Loss: 1.7444
# Epoch [5], Batch [150], Loss: 1.7429
# Epoch [5], Batch [200], Loss: 1.7181
# Epoch [5], Batch [250], Loss: 1.7375
# Epoch [5], Batch [300], Loss: 1.7044
# Epoch [5], Batch [350], Loss: 1.7124
# Epoch [6], Batch [50], Loss: 1.6964
# Epoch [6], Batch [100], Loss: 1.7016
# Epoch [6], Batch [150], Loss: 1.6820
# Epoch [6], Batch [200], Loss: 1.6635
# Epoch [6], Batch [250], Loss: 1.6558
# Epoch [6], Batch [300], Loss: 1.6561
# Epoch [6], Batch [350], Loss: 1.6490
# Epoch [7], Batch [50], Loss: 1.6372
# Epoch [7], Batch [100], Loss: 1.6364
# Epoch [7], Batch [150], Loss: 1.6388
# Epoch [7], Batch [200], Loss: 1.6566
# Epoch [7], Batch [250], Loss: 1.6316
# Epoch [7], Batch [300], Loss: 1.6205
# Epoch [7], Batch [350], Loss: 1.6083
# Epoch [8], Batch [50], Loss: 1.6064
# Epoch [8], Batch [100], Loss: 1.5872
# Epoch [8], Batch [150], Loss: 1.5940
# Epoch [8], Batch [200], Loss: 1.6147
# Epoch [8], Batch [250], Loss: 1.5773
# Epoch [8], Batch [300], Loss: 1.6037
# Epoch [8], Batch [350], Loss: 1.5764
# Epoch [9], Batch [50], Loss: 1.5767
# Epoch [9], Batch [100], Loss: 1.5819
# Epoch [9], Batch [150], Loss: 1.5406
# Epoch [9], Batch [200], Loss: 1.5541
# Epoch [9], Batch [250], Loss: 1.5775
# Epoch [9], Batch [300], Loss: 1.5393
# Epoch [9], Batch [350], Loss: 1.5402
# Epoch [10], Batch [50], Loss: 1.5017
# Epoch [10], Batch [100], Loss: 1.5276
# Epoch [10], Batch [150], Loss: 1.5387
# Epoch [10], Batch [200], Loss: 1.5167
# Epoch [10], Batch [250], Loss: 1.5276
# Epoch [10], Batch [300], Loss: 1.5363
# Epoch [10], Batch [350], Loss: 1.5132
# [I 2025-04-30 19:19:06,669] Trial 8 finished with value: 49.2 and parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5223425157847674, 'num_fc_units': 256, 'learning_rate': 0.0005816501334749713, 'optimizer': 'SGD'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 49.20%
# Starting trial 9 with parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.5032136854394988, 'num_fc_units': 256, 'learning_rate': 0.0006334259827603846, 'optimizer': 'SGD'}
# Epoch [1], Batch [50], Loss: 2.2934
# Epoch [1], Batch [100], Loss: 2.2635
# Epoch [1], Batch [150], Loss: 2.2264
# Epoch [1], Batch [200], Loss: 2.1859
# Epoch [1], Batch [250], Loss: 2.1417
# Epoch [1], Batch [300], Loss: 2.1020
# Epoch [1], Batch [350], Loss: 2.0699
# Epoch [2], Batch [50], Loss: 2.0141
# Epoch [2], Batch [100], Loss: 1.9996
# Epoch [2], Batch [150], Loss: 1.9674
# Epoch [2], Batch [200], Loss: 1.9493
# Epoch [2], Batch [250], Loss: 1.9124
# Epoch [2], Batch [300], Loss: 1.8955
# Epoch [2], Batch [350], Loss: 1.8898
# Epoch [3], Batch [50], Loss: 1.8514
# Epoch [3], Batch [100], Loss: 1.8345
# Epoch [3], Batch [150], Loss: 1.8215
# Epoch [3], Batch [200], Loss: 1.8208
# Epoch [3], Batch [250], Loss: 1.7983
# Epoch [3], Batch [300], Loss: 1.7592
# Epoch [3], Batch [350], Loss: 1.7735
# Epoch [4], Batch [50], Loss: 1.7281
# Epoch [4], Batch [100], Loss: 1.7489
# Epoch [4], Batch [150], Loss: 1.7056
# Epoch [4], Batch [200], Loss: 1.6938
# Epoch [4], Batch [250], Loss: 1.7024
# Epoch [4], Batch [300], Loss: 1.6828
# Epoch [4], Batch [350], Loss: 1.6909
# Epoch [5], Batch [50], Loss: 1.6562
# Epoch [5], Batch [100], Loss: 1.6549
# Epoch [5], Batch [150], Loss: 1.6223
# Epoch [5], Batch [200], Loss: 1.6225
# Epoch [5], Batch [250], Loss: 1.6037
# Epoch [5], Batch [300], Loss: 1.6095
# Epoch [5], Batch [350], Loss: 1.6091
# Epoch [6], Batch [50], Loss: 1.5820
# Epoch [6], Batch [100], Loss: 1.5642
# Epoch [6], Batch [150], Loss: 1.5651
# Epoch [6], Batch [200], Loss: 1.5525
# Epoch [6], Batch [250], Loss: 1.5613
# Epoch [6], Batch [300], Loss: 1.5515
# Epoch [6], Batch [350], Loss: 1.5442
# Epoch [7], Batch [50], Loss: 1.5266
# Epoch [7], Batch [100], Loss: 1.5270
# Epoch [7], Batch [150], Loss: 1.5101
# Epoch [7], Batch [200], Loss: 1.5001
# Epoch [7], Batch [250], Loss: 1.5230
# Epoch [7], Batch [300], Loss: 1.5163
# Epoch [7], Batch [350], Loss: 1.4811
# Epoch [8], Batch [50], Loss: 1.4600
# Epoch [8], Batch [100], Loss: 1.4871
# Epoch [8], Batch [150], Loss: 1.4527
# Epoch [8], Batch [200], Loss: 1.4714
# Epoch [8], Batch [250], Loss: 1.4515
# Epoch [8], Batch [300], Loss: 1.4612
# Epoch [8], Batch [350], Loss: 1.4490
# Epoch [9], Batch [50], Loss: 1.4399
# Epoch [9], Batch [100], Loss: 1.4335
# Epoch [9], Batch [150], Loss: 1.4243
# Epoch [9], Batch [200], Loss: 1.4336
# Epoch [9], Batch [250], Loss: 1.4052
# Epoch [9], Batch [300], Loss: 1.4379
# Epoch [9], Batch [350], Loss: 1.4294
# Epoch [10], Batch [50], Loss: 1.3954
# Epoch [10], Batch [100], Loss: 1.3821
# Epoch [10], Batch [150], Loss: 1.3896
# Epoch [10], Batch [200], Loss: 1.3966
# Epoch [10], Batch [250], Loss: 1.4138
# Epoch [10], Batch [300], Loss: 1.3898
# Epoch [10], Batch [350], Loss: 1.3880
# [I 2025-04-30 19:21:11,113] Trial 9 finished with value: 52.88 and parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.5032136854394988, 'num_fc_units': 256, 'learning_rate': 0.0006334259827603846, 'optimizer': 'SGD'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 52.88%
# Starting trial 10 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3071541117996135, 'num_fc_units': 512, 'learning_rate': 0.001977786026570212, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 2.0485
# Epoch [1], Batch [100], Loss: 1.6777
# Epoch [1], Batch [150], Loss: 1.5223
# Epoch [1], Batch [200], Loss: 1.4512
# Epoch [1], Batch [250], Loss: 1.3866
# Epoch [1], Batch [300], Loss: 1.3497
# Epoch [1], Batch [350], Loss: 1.2838
# Epoch [2], Batch [50], Loss: 1.1749
# Epoch [2], Batch [100], Loss: 1.1285
# Epoch [2], Batch [150], Loss: 1.1197
# Epoch [2], Batch [200], Loss: 1.1018
# Epoch [2], Batch [250], Loss: 1.0665
# Epoch [2], Batch [300], Loss: 1.0366
# Epoch [2], Batch [350], Loss: 1.0586
# Epoch [3], Batch [50], Loss: 0.9297
# Epoch [3], Batch [100], Loss: 0.9491
# Epoch [3], Batch [150], Loss: 0.9254
# Epoch [3], Batch [200], Loss: 0.9190
# Epoch [3], Batch [250], Loss: 0.8891
# Epoch [3], Batch [300], Loss: 0.9443
# Epoch [3], Batch [350], Loss: 0.9328
# Epoch [4], Batch [50], Loss: 0.7894
# Epoch [4], Batch [100], Loss: 0.8329
# Epoch [4], Batch [150], Loss: 0.8054
# Epoch [4], Batch [200], Loss: 0.7967
# Epoch [4], Batch [250], Loss: 0.8087
# Epoch [4], Batch [300], Loss: 0.7976
# Epoch [4], Batch [350], Loss: 0.8026
# Epoch [5], Batch [50], Loss: 0.7058
# Epoch [5], Batch [100], Loss: 0.6780
# Epoch [5], Batch [150], Loss: 0.7299
# Epoch [5], Batch [200], Loss: 0.7125
# Epoch [5], Batch [250], Loss: 0.7375
# Epoch [5], Batch [300], Loss: 0.7317
# Epoch [5], Batch [350], Loss: 0.7284
# Epoch [6], Batch [50], Loss: 0.6415
# Epoch [6], Batch [100], Loss: 0.6306
# Epoch [6], Batch [150], Loss: 0.6356
# Epoch [6], Batch [200], Loss: 0.6310
# Epoch [6], Batch [250], Loss: 0.6287
# Epoch [6], Batch [300], Loss: 0.6764
# Epoch [6], Batch [350], Loss: 0.6491
# Epoch [7], Batch [50], Loss: 0.5262
# Epoch [7], Batch [100], Loss: 0.5553
# Epoch [7], Batch [150], Loss: 0.5564
# Epoch [7], Batch [200], Loss: 0.6296
# Epoch [7], Batch [250], Loss: 0.6009
# Epoch [7], Batch [300], Loss: 0.5907
# Epoch [7], Batch [350], Loss: 0.5970
# Epoch [8], Batch [50], Loss: 0.4720
# Epoch [8], Batch [100], Loss: 0.4829
# Epoch [8], Batch [150], Loss: 0.5323
# Epoch [8], Batch [200], Loss: 0.5354
# Epoch [8], Batch [250], Loss: 0.5267
# Epoch [8], Batch [300], Loss: 0.5473
# Epoch [8], Batch [350], Loss: 0.5788
# Epoch [9], Batch [50], Loss: 0.4133
# Epoch [9], Batch [100], Loss: 0.4498
# Epoch [9], Batch [150], Loss: 0.4617
# Epoch [9], Batch [200], Loss: 0.5092
# Epoch [9], Batch [250], Loss: 0.4793
# Epoch [9], Batch [300], Loss: 0.4846
# Epoch [9], Batch [350], Loss: 0.4678
# Epoch [10], Batch [50], Loss: 0.3812
# Epoch [10], Batch [100], Loss: 0.3973
# Epoch [10], Batch [150], Loss: 0.4040
# Epoch [10], Batch [200], Loss: 0.4228
# Epoch [10], Batch [250], Loss: 0.4393
# Epoch [10], Batch [300], Loss: 0.4384
# Epoch [10], Batch [350], Loss: 0.4652
# [I 2025-04-30 19:23:25,281] Trial 10 finished with value: 74.4 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3071541117996135, 'num_fc_units': 512, 'learning_rate': 0.001977786026570212, 'optimizer': 'Adam'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 74.40%
# Starting trial 11 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3303912991764401, 'num_fc_units': 512, 'learning_rate': 0.001992808018533275, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 2.0384
# Epoch [1], Batch [100], Loss: 1.6553
# Epoch [1], Batch [150], Loss: 1.5012
# Epoch [1], Batch [200], Loss: 1.4323
# Epoch [1], Batch [250], Loss: 1.3193
# Epoch [1], Batch [300], Loss: 1.2722
# Epoch [1], Batch [350], Loss: 1.2537
# Epoch [2], Batch [50], Loss: 1.0830
# Epoch [2], Batch [100], Loss: 1.0581
# Epoch [2], Batch [150], Loss: 1.0385
# Epoch [2], Batch [200], Loss: 1.0046
# Epoch [2], Batch [250], Loss: 1.0082
# Epoch [2], Batch [300], Loss: 0.9947
# Epoch [2], Batch [350], Loss: 0.9517
# Epoch [3], Batch [50], Loss: 0.8315
# Epoch [3], Batch [100], Loss: 0.8460
# Epoch [3], Batch [150], Loss: 0.8216
# Epoch [3], Batch [200], Loss: 0.8273
# Epoch [3], Batch [250], Loss: 0.8418
# Epoch [3], Batch [300], Loss: 0.8154
# Epoch [3], Batch [350], Loss: 0.8176
# Epoch [4], Batch [50], Loss: 0.7425
# Epoch [4], Batch [100], Loss: 0.7185
# Epoch [4], Batch [150], Loss: 0.7041
# Epoch [4], Batch [200], Loss: 0.7106
# Epoch [4], Batch [250], Loss: 0.7152
# Epoch [4], Batch [300], Loss: 0.7038
# Epoch [4], Batch [350], Loss: 0.7417
# Epoch [5], Batch [50], Loss: 0.5930
# Epoch [5], Batch [100], Loss: 0.6077
# Epoch [5], Batch [150], Loss: 0.6022
# Epoch [5], Batch [200], Loss: 0.6463
# Epoch [5], Batch [250], Loss: 0.6191
# Epoch [5], Batch [300], Loss: 0.6462
# Epoch [5], Batch [350], Loss: 0.6691
# Epoch [6], Batch [50], Loss: 0.5065
# Epoch [6], Batch [100], Loss: 0.5277
# Epoch [6], Batch [150], Loss: 0.5413
# Epoch [6], Batch [200], Loss: 0.5669
# Epoch [6], Batch [250], Loss: 0.5936
# Epoch [6], Batch [300], Loss: 0.5845
# Epoch [6], Batch [350], Loss: 0.5747
# Epoch [7], Batch [50], Loss: 0.4271
# Epoch [7], Batch [100], Loss: 0.4627
# Epoch [7], Batch [150], Loss: 0.4983
# Epoch [7], Batch [200], Loss: 0.4843
# Epoch [7], Batch [250], Loss: 0.5236
# Epoch [7], Batch [300], Loss: 0.5290
# Epoch [7], Batch [350], Loss: 0.5137
# Epoch [8], Batch [50], Loss: 0.4137
# Epoch [8], Batch [100], Loss: 0.4120
# Epoch [8], Batch [150], Loss: 0.4782
# Epoch [8], Batch [200], Loss: 0.4562
# Epoch [8], Batch [250], Loss: 0.4476
# Epoch [8], Batch [300], Loss: 0.4839
# Epoch [8], Batch [350], Loss: 0.4776
# Epoch [9], Batch [50], Loss: 0.3459
# Epoch [9], Batch [100], Loss: 0.3497
# Epoch [9], Batch [150], Loss: 0.3957
# Epoch [9], Batch [200], Loss: 0.4062
# Epoch [9], Batch [250], Loss: 0.4141
# Epoch [9], Batch [300], Loss: 0.4393
# Epoch [9], Batch [350], Loss: 0.4089
# Epoch [10], Batch [50], Loss: 0.3214
# Epoch [10], Batch [100], Loss: 0.3475
# Epoch [10], Batch [150], Loss: 0.3428
# Epoch [10], Batch [200], Loss: 0.3541
# Epoch [10], Batch [250], Loss: 0.3765
# Epoch [10], Batch [300], Loss: 0.3874
# Epoch [10], Batch [350], Loss: 0.3809
# [I 2025-04-30 19:25:40,070] Trial 11 finished with value: 75.07 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3303912991764401, 'num_fc_units': 512, 'learning_rate': 0.001992808018533275, 'optimizer': 'Adam'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 75.07%
# Starting trial 12 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3680860957000469, 'num_fc_units': 512, 'learning_rate': 0.0021392704080822477, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 2.0412
# Epoch [1], Batch [100], Loss: 1.6947
# Epoch [1], Batch [150], Loss: 1.5076
# Epoch [1], Batch [200], Loss: 1.3913
# Epoch [1], Batch [250], Loss: 1.3210
# Epoch [1], Batch [300], Loss: 1.2564
# Epoch [1], Batch [350], Loss: 1.2308
# Epoch [2], Batch [50], Loss: 1.0985
# Epoch [2], Batch [100], Loss: 1.0637
# Epoch [2], Batch [150], Loss: 1.0550
# Epoch [2], Batch [200], Loss: 1.0526
# Epoch [2], Batch [250], Loss: 1.0059
# Epoch [2], Batch [300], Loss: 0.9545
# Epoch [2], Batch [350], Loss: 0.9868
# Epoch [3], Batch [50], Loss: 0.8552
# Epoch [3], Batch [100], Loss: 0.8649
# Epoch [3], Batch [150], Loss: 0.9102
# Epoch [3], Batch [200], Loss: 0.8512
# Epoch [3], Batch [250], Loss: 0.8917
# Epoch [3], Batch [300], Loss: 0.8458
# Epoch [3], Batch [350], Loss: 0.8464
# Epoch [4], Batch [50], Loss: 0.7412
# Epoch [4], Batch [100], Loss: 0.7546
# Epoch [4], Batch [150], Loss: 0.7543
# Epoch [4], Batch [200], Loss: 0.7396
# Epoch [4], Batch [250], Loss: 0.7373
# Epoch [4], Batch [300], Loss: 0.7567
# Epoch [4], Batch [350], Loss: 0.7682
# Epoch [5], Batch [50], Loss: 0.6573
# Epoch [5], Batch [100], Loss: 0.6670
# Epoch [5], Batch [150], Loss: 0.6680
# Epoch [5], Batch [200], Loss: 0.6717
# Epoch [5], Batch [250], Loss: 0.6704
# Epoch [5], Batch [300], Loss: 0.6852
# Epoch [5], Batch [350], Loss: 0.6851
# Epoch [6], Batch [50], Loss: 0.5760
# Epoch [6], Batch [100], Loss: 0.5734
# Epoch [6], Batch [150], Loss: 0.6013
# Epoch [6], Batch [200], Loss: 0.6074
# Epoch [6], Batch [250], Loss: 0.6061
# Epoch [6], Batch [300], Loss: 0.6509
# Epoch [6], Batch [350], Loss: 0.6308
# Epoch [7], Batch [50], Loss: 0.5232
# Epoch [7], Batch [100], Loss: 0.5446
# Epoch [7], Batch [150], Loss: 0.5500
# Epoch [7], Batch [200], Loss: 0.5908
# Epoch [7], Batch [250], Loss: 0.5687
# Epoch [7], Batch [300], Loss: 0.5650
# Epoch [7], Batch [350], Loss: 0.5592
# Epoch [8], Batch [50], Loss: 0.4926
# Epoch [8], Batch [100], Loss: 0.4890
# Epoch [8], Batch [150], Loss: 0.4883
# Epoch [8], Batch [200], Loss: 0.5075
# Epoch [8], Batch [250], Loss: 0.5167
# Epoch [8], Batch [300], Loss: 0.5274
# Epoch [8], Batch [350], Loss: 0.5178
# Epoch [9], Batch [50], Loss: 0.4157
# Epoch [9], Batch [100], Loss: 0.4299
# Epoch [9], Batch [150], Loss: 0.4670
# Epoch [9], Batch [200], Loss: 0.4791
# Epoch [9], Batch [250], Loss: 0.4676
# Epoch [9], Batch [300], Loss: 0.5047
# Epoch [9], Batch [350], Loss: 0.4884
# Epoch [10], Batch [50], Loss: 0.4008
# Epoch [10], Batch [100], Loss: 0.3866
# Epoch [10], Batch [150], Loss: 0.4279
# Epoch [10], Batch [200], Loss: 0.4246
# Epoch [10], Batch [250], Loss: 0.4360
# Epoch [10], Batch [300], Loss: 0.4671
# Epoch [10], Batch [350], Loss: 0.4467
# [I 2025-04-30 19:27:54,882] Trial 12 finished with value: 75.18 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.3680860957000469, 'num_fc_units': 512, 'learning_rate': 0.0021392704080822477, 'optimizer': 'Adam'}. Best is trial 6 with value: 78.76.
# Test Accuracy: 75.18%
# Starting trial 13 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.42541390946706564, 'num_fc_units': 512, 'learning_rate': 0.0009755040618102396, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9609
# Epoch [1], Batch [100], Loss: 1.6736
# Epoch [1], Batch [150], Loss: 1.4832
# Epoch [1], Batch [200], Loss: 1.4271
# Epoch [1], Batch [250], Loss: 1.3202
# Epoch [1], Batch [300], Loss: 1.2843
# Epoch [1], Batch [350], Loss: 1.2096
# Epoch [2], Batch [50], Loss: 1.0802
# Epoch [2], Batch [100], Loss: 1.0603
# Epoch [2], Batch [150], Loss: 1.0111
# Epoch [2], Batch [200], Loss: 0.9921
# Epoch [2], Batch [250], Loss: 0.9950
# Epoch [2], Batch [300], Loss: 0.9694
# Epoch [2], Batch [350], Loss: 0.9259
# Epoch [3], Batch [50], Loss: 0.8500
# Epoch [3], Batch [100], Loss: 0.8295
# Epoch [3], Batch [150], Loss: 0.8168
# Epoch [3], Batch [200], Loss: 0.7787
# Epoch [3], Batch [250], Loss: 0.8109
# Epoch [3], Batch [300], Loss: 0.7590
# Epoch [3], Batch [350], Loss: 0.7752
# Epoch [4], Batch [50], Loss: 0.6902
# Epoch [4], Batch [100], Loss: 0.6752
# Epoch [4], Batch [150], Loss: 0.6623
# Epoch [4], Batch [200], Loss: 0.6653
# Epoch [4], Batch [250], Loss: 0.6649
# Epoch [4], Batch [300], Loss: 0.6617
# Epoch [4], Batch [350], Loss: 0.6789
# Epoch [5], Batch [50], Loss: 0.5470
# Epoch [5], Batch [100], Loss: 0.5698
# Epoch [5], Batch [150], Loss: 0.5482
# Epoch [5], Batch [200], Loss: 0.5576
# Epoch [5], Batch [250], Loss: 0.5605
# Epoch [5], Batch [300], Loss: 0.5748
# Epoch [5], Batch [350], Loss: 0.5781
# Epoch [6], Batch [50], Loss: 0.4633
# Epoch [6], Batch [100], Loss: 0.4545
# Epoch [6], Batch [150], Loss: 0.4933
# Epoch [6], Batch [200], Loss: 0.4736
# Epoch [6], Batch [250], Loss: 0.4762
# Epoch [6], Batch [300], Loss: 0.4754
# Epoch [6], Batch [350], Loss: 0.5053
# Epoch [7], Batch [50], Loss: 0.3949
# Epoch [7], Batch [100], Loss: 0.3914
# Epoch [7], Batch [150], Loss: 0.3883
# Epoch [7], Batch [200], Loss: 0.4123
# Epoch [7], Batch [250], Loss: 0.3973
# Epoch [7], Batch [300], Loss: 0.3975
# Epoch [7], Batch [350], Loss: 0.4082
# Epoch [8], Batch [50], Loss: 0.3103
# Epoch [8], Batch [100], Loss: 0.3189
# Epoch [8], Batch [150], Loss: 0.3145
# Epoch [8], Batch [200], Loss: 0.3486
# Epoch [8], Batch [250], Loss: 0.3432
# Epoch [8], Batch [300], Loss: 0.3668
# Epoch [8], Batch [350], Loss: 0.3497
# Epoch [9], Batch [50], Loss: 0.2660
# Epoch [9], Batch [100], Loss: 0.2449
# Epoch [9], Batch [150], Loss: 0.2565
# Epoch [9], Batch [200], Loss: 0.2942
# Epoch [9], Batch [250], Loss: 0.2808
# Epoch [9], Batch [300], Loss: 0.2894
# Epoch [9], Batch [350], Loss: 0.3007
# Epoch [10], Batch [50], Loss: 0.2065
# Epoch [10], Batch [100], Loss: 0.2182
# Epoch [10], Batch [150], Loss: 0.2240
# Epoch [10], Batch [200], Loss: 0.2260
# Epoch [10], Batch [250], Loss: 0.2388
# Epoch [10], Batch [300], Loss: 0.2522
# Epoch [10], Batch [350], Loss: 0.2697
# [I 2025-04-30 19:30:09,890] Trial 13 finished with value: 79.03 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.42541390946706564, 'num_fc_units': 512, 'learning_rate': 0.0009755040618102396, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 79.03%
# Starting trial 14 with parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4317687544355828, 'num_fc_units': 512, 'learning_rate': 0.0009749898171290238, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9155
# Epoch [1], Batch [100], Loss: 1.5690
# Epoch [1], Batch [150], Loss: 1.4088
# Epoch [1], Batch [200], Loss: 1.3438
# Epoch [1], Batch [250], Loss: 1.2871
# Epoch [1], Batch [300], Loss: 1.2498
# Epoch [1], Batch [350], Loss: 1.1844
# Epoch [2], Batch [50], Loss: 1.0951
# Epoch [2], Batch [100], Loss: 1.0246
# Epoch [2], Batch [150], Loss: 1.0185
# Epoch [2], Batch [200], Loss: 1.0362
# Epoch [2], Batch [250], Loss: 0.9982
# Epoch [2], Batch [300], Loss: 0.9911
# Epoch [2], Batch [350], Loss: 0.9579
# Epoch [3], Batch [50], Loss: 0.8610
# Epoch [3], Batch [100], Loss: 0.8707
# Epoch [3], Batch [150], Loss: 0.8469
# Epoch [3], Batch [200], Loss: 0.8784
# Epoch [3], Batch [250], Loss: 0.8518
# Epoch [3], Batch [300], Loss: 0.8217
# Epoch [3], Batch [350], Loss: 0.8461
# Epoch [4], Batch [50], Loss: 0.7158
# Epoch [4], Batch [100], Loss: 0.7472
# Epoch [4], Batch [150], Loss: 0.7417
# Epoch [4], Batch [200], Loss: 0.7276
# Epoch [4], Batch [250], Loss: 0.7481
# Epoch [4], Batch [300], Loss: 0.7512
# Epoch [4], Batch [350], Loss: 0.7301
# Epoch [5], Batch [50], Loss: 0.6206
# Epoch [5], Batch [100], Loss: 0.6273
# Epoch [5], Batch [150], Loss: 0.6362
# Epoch [5], Batch [200], Loss: 0.6448
# Epoch [5], Batch [250], Loss: 0.6393
# Epoch [5], Batch [300], Loss: 0.6418
# Epoch [5], Batch [350], Loss: 0.6542
# Epoch [6], Batch [50], Loss: 0.5480
# Epoch [6], Batch [100], Loss: 0.5293
# Epoch [6], Batch [150], Loss: 0.5450
# Epoch [6], Batch [200], Loss: 0.5636
# Epoch [6], Batch [250], Loss: 0.5650
# Epoch [6], Batch [300], Loss: 0.5653
# Epoch [6], Batch [350], Loss: 0.5529
# Epoch [7], Batch [50], Loss: 0.4624
# Epoch [7], Batch [100], Loss: 0.4476
# Epoch [7], Batch [150], Loss: 0.4574
# Epoch [7], Batch [200], Loss: 0.4876
# Epoch [7], Batch [250], Loss: 0.5011
# Epoch [7], Batch [300], Loss: 0.5026
# Epoch [7], Batch [350], Loss: 0.5020
# Epoch [8], Batch [50], Loss: 0.3777
# Epoch [8], Batch [100], Loss: 0.3972
# Epoch [8], Batch [150], Loss: 0.4030
# Epoch [8], Batch [200], Loss: 0.4294
# Epoch [8], Batch [250], Loss: 0.4188
# Epoch [8], Batch [300], Loss: 0.4274
# Epoch [8], Batch [350], Loss: 0.4364
# Epoch [9], Batch [50], Loss: 0.3348
# Epoch [9], Batch [100], Loss: 0.3315
# Epoch [9], Batch [150], Loss: 0.3452
# Epoch [9], Batch [200], Loss: 0.3578
# Epoch [9], Batch [250], Loss: 0.3553
# Epoch [9], Batch [300], Loss: 0.3752
# Epoch [9], Batch [350], Loss: 0.3946
# Epoch [10], Batch [50], Loss: 0.2782
# Epoch [10], Batch [100], Loss: 0.2689
# Epoch [10], Batch [150], Loss: 0.3028
# Epoch [10], Batch [200], Loss: 0.3051
# Epoch [10], Batch [250], Loss: 0.3179
# Epoch [10], Batch [300], Loss: 0.3234
# Epoch [10], Batch [350], Loss: 0.3265
# [I 2025-04-30 19:32:22,990] Trial 14 finished with value: 75.36 and parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4317687544355828, 'num_fc_units': 512, 'learning_rate': 0.0009749898171290238, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 75.36%
# Starting trial 15 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.458720521751059, 'num_fc_units': 512, 'learning_rate': 0.0008710258996970458, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9745
# Epoch [1], Batch [100], Loss: 1.6840
# Epoch [1], Batch [150], Loss: 1.5277
# Epoch [1], Batch [200], Loss: 1.4369
# Epoch [1], Batch [250], Loss: 1.3465
# Epoch [1], Batch [300], Loss: 1.2868
# Epoch [1], Batch [350], Loss: 1.2415
# Epoch [2], Batch [50], Loss: 1.1529
# Epoch [2], Batch [100], Loss: 1.1305
# Epoch [2], Batch [150], Loss: 1.0515
# Epoch [2], Batch [200], Loss: 1.0357
# Epoch [2], Batch [250], Loss: 1.0024
# Epoch [2], Batch [300], Loss: 0.9739
# Epoch [2], Batch [350], Loss: 0.9746
# Epoch [3], Batch [50], Loss: 0.8959
# Epoch [3], Batch [100], Loss: 0.8417
# Epoch [3], Batch [150], Loss: 0.8638
# Epoch [3], Batch [200], Loss: 0.8321
# Epoch [3], Batch [250], Loss: 0.8464
# Epoch [3], Batch [300], Loss: 0.8037
# Epoch [3], Batch [350], Loss: 0.8290
# Epoch [4], Batch [50], Loss: 0.7228
# Epoch [4], Batch [100], Loss: 0.6998
# Epoch [4], Batch [150], Loss: 0.7309
# Epoch [4], Batch [200], Loss: 0.7143
# Epoch [4], Batch [250], Loss: 0.7168
# Epoch [4], Batch [300], Loss: 0.7079
# Epoch [4], Batch [350], Loss: 0.6918
# Epoch [5], Batch [50], Loss: 0.6080
# Epoch [5], Batch [100], Loss: 0.6138
# Epoch [5], Batch [150], Loss: 0.5817
# Epoch [5], Batch [200], Loss: 0.6152
# Epoch [5], Batch [250], Loss: 0.6185
# Epoch [5], Batch [300], Loss: 0.5978
# Epoch [5], Batch [350], Loss: 0.6423
# Epoch [6], Batch [50], Loss: 0.5328
# Epoch [6], Batch [100], Loss: 0.5202
# Epoch [6], Batch [150], Loss: 0.5199
# Epoch [6], Batch [200], Loss: 0.5243
# Epoch [6], Batch [250], Loss: 0.5203
# Epoch [6], Batch [300], Loss: 0.5412
# Epoch [6], Batch [350], Loss: 0.5355
# Epoch [7], Batch [50], Loss: 0.4268
# Epoch [7], Batch [100], Loss: 0.4462
# Epoch [7], Batch [150], Loss: 0.4533
# Epoch [7], Batch [200], Loss: 0.4403
# Epoch [7], Batch [250], Loss: 0.4754
# Epoch [7], Batch [300], Loss: 0.4897
# Epoch [7], Batch [350], Loss: 0.4584
# Epoch [8], Batch [50], Loss: 0.3619
# Epoch [8], Batch [100], Loss: 0.3741
# Epoch [8], Batch [150], Loss: 0.3998
# Epoch [8], Batch [200], Loss: 0.3736
# Epoch [8], Batch [250], Loss: 0.3923
# Epoch [8], Batch [300], Loss: 0.3901
# Epoch [8], Batch [350], Loss: 0.4372
# Epoch [9], Batch [50], Loss: 0.3116
# Epoch [9], Batch [100], Loss: 0.3051
# Epoch [9], Batch [150], Loss: 0.2993
# Epoch [9], Batch [200], Loss: 0.3258
# Epoch [9], Batch [250], Loss: 0.3441
# Epoch [9], Batch [300], Loss: 0.3604
# Epoch [9], Batch [350], Loss: 0.3560
# Epoch [10], Batch [50], Loss: 0.2497
# Epoch [10], Batch [100], Loss: 0.2665
# Epoch [10], Batch [150], Loss: 0.2794
# Epoch [10], Batch [200], Loss: 0.2518
# Epoch [10], Batch [250], Loss: 0.3018
# Epoch [10], Batch [300], Loss: 0.2986
# Epoch [10], Batch [350], Loss: 0.3139
# [I 2025-04-30 19:34:36,544] Trial 15 finished with value: 78.85 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.458720521751059, 'num_fc_units': 512, 'learning_rate': 0.0008710258996970458, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 78.85%
# Starting trial 16 with parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4687330332543583, 'num_fc_units': 512, 'learning_rate': 0.0014380542418924416, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9210
# Epoch [1], Batch [100], Loss: 1.5715
# Epoch [1], Batch [150], Loss: 1.4355
# Epoch [1], Batch [200], Loss: 1.4060
# Epoch [1], Batch [250], Loss: 1.3461
# Epoch [1], Batch [300], Loss: 1.2744
# Epoch [1], Batch [350], Loss: 1.2309
# Epoch [2], Batch [50], Loss: 1.1158
# Epoch [2], Batch [100], Loss: 1.0737
# Epoch [2], Batch [150], Loss: 1.0898
# Epoch [2], Batch [200], Loss: 1.0428
# Epoch [2], Batch [250], Loss: 1.0569
# Epoch [2], Batch [300], Loss: 1.0598
# Epoch [2], Batch [350], Loss: 1.0044
# Epoch [3], Batch [50], Loss: 0.9520
# Epoch [3], Batch [100], Loss: 0.9196
# Epoch [3], Batch [150], Loss: 0.9328
# Epoch [3], Batch [200], Loss: 0.9000
# Epoch [3], Batch [250], Loss: 0.9109
# Epoch [3], Batch [300], Loss: 0.8888
# Epoch [3], Batch [350], Loss: 0.8979
# Epoch [4], Batch [50], Loss: 0.8123
# Epoch [4], Batch [100], Loss: 0.8225
# Epoch [4], Batch [150], Loss: 0.8128
# Epoch [4], Batch [200], Loss: 0.8325
# Epoch [4], Batch [250], Loss: 0.8084
# Epoch [4], Batch [300], Loss: 0.8105
# Epoch [4], Batch [350], Loss: 0.8128
# Epoch [5], Batch [50], Loss: 0.7114
# Epoch [5], Batch [100], Loss: 0.7093
# Epoch [5], Batch [150], Loss: 0.7410
# Epoch [5], Batch [200], Loss: 0.7453
# Epoch [5], Batch [250], Loss: 0.7433
# Epoch [5], Batch [300], Loss: 0.7379
# Epoch [5], Batch [350], Loss: 0.7519
# Epoch [6], Batch [50], Loss: 0.6400
# Epoch [6], Batch [100], Loss: 0.6441
# Epoch [6], Batch [150], Loss: 0.6472
# Epoch [6], Batch [200], Loss: 0.6630
# Epoch [6], Batch [250], Loss: 0.6803
# Epoch [6], Batch [300], Loss: 0.6741
# Epoch [6], Batch [350], Loss: 0.6646
# Epoch [7], Batch [50], Loss: 0.5759
# Epoch [7], Batch [100], Loss: 0.5719
# Epoch [7], Batch [150], Loss: 0.5965
# Epoch [7], Batch [200], Loss: 0.6184
# Epoch [7], Batch [250], Loss: 0.6125
# Epoch [7], Batch [300], Loss: 0.6040
# Epoch [7], Batch [350], Loss: 0.6202
# Epoch [8], Batch [50], Loss: 0.5179
# Epoch [8], Batch [100], Loss: 0.5154
# Epoch [8], Batch [150], Loss: 0.5473
# Epoch [8], Batch [200], Loss: 0.5395
# Epoch [8], Batch [250], Loss: 0.5596
# Epoch [8], Batch [300], Loss: 0.5805
# Epoch [8], Batch [350], Loss: 0.5790
# Epoch [9], Batch [50], Loss: 0.4659
# Epoch [9], Batch [100], Loss: 0.4718
# Epoch [9], Batch [150], Loss: 0.4931
# Epoch [9], Batch [200], Loss: 0.5056
# Epoch [9], Batch [250], Loss: 0.5001
# Epoch [9], Batch [300], Loss: 0.5325
# Epoch [9], Batch [350], Loss: 0.5237
# Epoch [10], Batch [50], Loss: 0.4329
# Epoch [10], Batch [100], Loss: 0.4180
# Epoch [10], Batch [150], Loss: 0.4605
# Epoch [10], Batch [200], Loss: 0.4672
# Epoch [10], Batch [250], Loss: 0.4646
# Epoch [10], Batch [300], Loss: 0.5038
# Epoch [10], Batch [350], Loss: 0.4710
# [I 2025-04-30 19:36:49,171] Trial 16 finished with value: 75.05 and parameters: {'num_conv_layers': 2, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4687330332543583, 'num_fc_units': 512, 'learning_rate': 0.0014380542418924416, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 75.05%
# Starting trial 17 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.46839289896107134, 'num_fc_units': 512, 'learning_rate': 0.0008682450528184609, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9575
# Epoch [1], Batch [100], Loss: 1.6113
# Epoch [1], Batch [150], Loss: 1.4863
# Epoch [1], Batch [200], Loss: 1.4153
# Epoch [1], Batch [250], Loss: 1.3240
# Epoch [1], Batch [300], Loss: 1.3100
# Epoch [1], Batch [350], Loss: 1.2040
# Epoch [2], Batch [50], Loss: 1.1097
# Epoch [2], Batch [100], Loss: 1.0480
# Epoch [2], Batch [150], Loss: 1.0353
# Epoch [2], Batch [200], Loss: 1.0157
# Epoch [2], Batch [250], Loss: 0.9837
# Epoch [2], Batch [300], Loss: 0.9784
# Epoch [2], Batch [350], Loss: 0.9407
# Epoch [3], Batch [50], Loss: 0.8140
# Epoch [3], Batch [100], Loss: 0.8239
# Epoch [3], Batch [150], Loss: 0.8500
# Epoch [3], Batch [200], Loss: 0.8090
# Epoch [3], Batch [250], Loss: 0.8352
# Epoch [3], Batch [300], Loss: 0.7932
# Epoch [3], Batch [350], Loss: 0.8088
# Epoch [4], Batch [50], Loss: 0.6875
# Epoch [4], Batch [100], Loss: 0.6891
# Epoch [4], Batch [150], Loss: 0.6851
# Epoch [4], Batch [200], Loss: 0.6796
# Epoch [4], Batch [250], Loss: 0.6795
# Epoch [4], Batch [300], Loss: 0.6815
# Epoch [4], Batch [350], Loss: 0.6750
# Epoch [5], Batch [50], Loss: 0.5788
# Epoch [5], Batch [100], Loss: 0.5806
# Epoch [5], Batch [150], Loss: 0.5783
# Epoch [5], Batch [200], Loss: 0.5847
# Epoch [5], Batch [250], Loss: 0.5966
# Epoch [5], Batch [300], Loss: 0.6095
# Epoch [5], Batch [350], Loss: 0.5836
# Epoch [6], Batch [50], Loss: 0.4817
# Epoch [6], Batch [100], Loss: 0.4791
# Epoch [6], Batch [150], Loss: 0.5058
# Epoch [6], Batch [200], Loss: 0.5208
# Epoch [6], Batch [250], Loss: 0.5150
# Epoch [6], Batch [300], Loss: 0.5005
# Epoch [6], Batch [350], Loss: 0.5274
# Epoch [7], Batch [50], Loss: 0.4119
# Epoch [7], Batch [100], Loss: 0.4125
# Epoch [7], Batch [150], Loss: 0.4026
# Epoch [7], Batch [200], Loss: 0.4365
# Epoch [7], Batch [250], Loss: 0.4232
# Epoch [7], Batch [300], Loss: 0.4476
# Epoch [7], Batch [350], Loss: 0.4506
# Epoch [8], Batch [50], Loss: 0.3397
# Epoch [8], Batch [100], Loss: 0.3435
# Epoch [8], Batch [150], Loss: 0.3587
# Epoch [8], Batch [200], Loss: 0.3513
# Epoch [8], Batch [250], Loss: 0.3527
# Epoch [8], Batch [300], Loss: 0.3898
# Epoch [8], Batch [350], Loss: 0.3956
# Epoch [9], Batch [50], Loss: 0.2726
# Epoch [9], Batch [100], Loss: 0.2949
# Epoch [9], Batch [150], Loss: 0.2841
# Epoch [9], Batch [200], Loss: 0.3028
# Epoch [9], Batch [250], Loss: 0.3153
# Epoch [9], Batch [300], Loss: 0.3210
# Epoch [9], Batch [350], Loss: 0.3320
# Epoch [10], Batch [50], Loss: 0.2277
# Epoch [10], Batch [100], Loss: 0.2372
# Epoch [10], Batch [150], Loss: 0.2316
# Epoch [10], Batch [200], Loss: 0.2692
# Epoch [10], Batch [250], Loss: 0.2677
# Epoch [10], Batch [300], Loss: 0.2701
# Epoch [10], Batch [350], Loss: 0.2736
# [I 2025-04-30 19:39:03,147] Trial 17 finished with value: 78.92 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.46839289896107134, 'num_fc_units': 512, 'learning_rate': 0.0008682450528184609, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 78.92%
# Starting trial 18 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.23353548891977116, 'num_fc_units': 512, 'learning_rate': 0.000783606695073347, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 1.9229
# Epoch [1], Batch [100], Loss: 1.5955
# Epoch [1], Batch [150], Loss: 1.4329
# Epoch [1], Batch [200], Loss: 1.3292
# Epoch [1], Batch [250], Loss: 1.2888
# Epoch [1], Batch [300], Loss: 1.2095
# Epoch [1], Batch [350], Loss: 1.1719
# Epoch [2], Batch [50], Loss: 1.0335
# Epoch [2], Batch [100], Loss: 1.0206
# Epoch [2], Batch [150], Loss: 0.9988
# Epoch [2], Batch [200], Loss: 0.9577
# Epoch [2], Batch [250], Loss: 0.9506
# Epoch [2], Batch [300], Loss: 0.9154
# Epoch [2], Batch [350], Loss: 0.8908
# Epoch [3], Batch [50], Loss: 0.7896
# Epoch [3], Batch [100], Loss: 0.7736
# Epoch [3], Batch [150], Loss: 0.7774
# Epoch [3], Batch [200], Loss: 0.7688
# Epoch [3], Batch [250], Loss: 0.7649
# Epoch [3], Batch [300], Loss: 0.7273
# Epoch [3], Batch [350], Loss: 0.7262
# Epoch [4], Batch [50], Loss: 0.6296
# Epoch [4], Batch [100], Loss: 0.6281
# Epoch [4], Batch [150], Loss: 0.6444
# Epoch [4], Batch [200], Loss: 0.6190
# Epoch [4], Batch [250], Loss: 0.6126
# Epoch [4], Batch [300], Loss: 0.6353
# Epoch [4], Batch [350], Loss: 0.6329
# Epoch [5], Batch [50], Loss: 0.5041
# Epoch [5], Batch [100], Loss: 0.5261
# Epoch [5], Batch [150], Loss: 0.5279
# Epoch [5], Batch [200], Loss: 0.5166
# Epoch [5], Batch [250], Loss: 0.4937
# Epoch [5], Batch [300], Loss: 0.5352
# Epoch [5], Batch [350], Loss: 0.5108
# Epoch [6], Batch [50], Loss: 0.4013
# Epoch [6], Batch [100], Loss: 0.3929
# Epoch [6], Batch [150], Loss: 0.4212
# Epoch [6], Batch [200], Loss: 0.4272
# Epoch [6], Batch [250], Loss: 0.4399
# Epoch [6], Batch [300], Loss: 0.4312
# Epoch [6], Batch [350], Loss: 0.4273
# Epoch [7], Batch [50], Loss: 0.3091
# Epoch [7], Batch [100], Loss: 0.3155
# Epoch [7], Batch [150], Loss: 0.3283
# Epoch [7], Batch [200], Loss: 0.3323
# Epoch [7], Batch [250], Loss: 0.3622
# Epoch [7], Batch [300], Loss: 0.3424
# Epoch [7], Batch [350], Loss: 0.3675
# Epoch [8], Batch [50], Loss: 0.2349
# Epoch [8], Batch [100], Loss: 0.2399
# Epoch [8], Batch [150], Loss: 0.2495
# Epoch [8], Batch [200], Loss: 0.2671
# Epoch [8], Batch [250], Loss: 0.2821
# Epoch [8], Batch [300], Loss: 0.2675
# Epoch [8], Batch [350], Loss: 0.2803
# Epoch [9], Batch [50], Loss: 0.1744
# Epoch [9], Batch [100], Loss: 0.1883
# Epoch [9], Batch [150], Loss: 0.1840
# Epoch [9], Batch [200], Loss: 0.1934
# Epoch [9], Batch [250], Loss: 0.2206
# Epoch [9], Batch [300], Loss: 0.2109
# Epoch [9], Batch [350], Loss: 0.2217
# Epoch [10], Batch [50], Loss: 0.1463
# Epoch [10], Batch [100], Loss: 0.1421
# Epoch [10], Batch [150], Loss: 0.1482
# Epoch [10], Batch [200], Loss: 0.1583
# Epoch [10], Batch [250], Loss: 0.1761
# Epoch [10], Batch [300], Loss: 0.1886
# Epoch [10], Batch [350], Loss: 0.1816
# [I 2025-04-30 19:41:17,922] Trial 18 finished with value: 78.17 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.23353548891977116, 'num_fc_units': 512, 'learning_rate': 0.000783606695073347, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 78.17%
# Starting trial 19 with parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4870154347906195, 'num_fc_units': 512, 'learning_rate': 0.0005047891987218423, 'optimizer': 'Adam'}
# Epoch [1], Batch [50], Loss: 2.0634
# Epoch [1], Batch [100], Loss: 1.7235
# Epoch [1], Batch [150], Loss: 1.5528
# Epoch [1], Batch [200], Loss: 1.4879
# Epoch [1], Batch [250], Loss: 1.4188
# Epoch [1], Batch [300], Loss: 1.3669
# Epoch [1], Batch [350], Loss: 1.3544
# Epoch [2], Batch [50], Loss: 1.2441
# Epoch [2], Batch [100], Loss: 1.2123
# Epoch [2], Batch [150], Loss: 1.1507
# Epoch [2], Batch [200], Loss: 1.1298
# Epoch [2], Batch [250], Loss: 1.1255
# Epoch [2], Batch [300], Loss: 1.0951
# Epoch [2], Batch [350], Loss: 1.0638
# Epoch [3], Batch [50], Loss: 0.9991
# Epoch [3], Batch [100], Loss: 0.9765
# Epoch [3], Batch [150], Loss: 0.9607
# Epoch [3], Batch [200], Loss: 0.9557
# Epoch [3], Batch [250], Loss: 0.9007
# Epoch [3], Batch [300], Loss: 0.9131
# Epoch [3], Batch [350], Loss: 0.8962
# Epoch [4], Batch [50], Loss: 0.8231
# Epoch [4], Batch [100], Loss: 0.8245
# Epoch [4], Batch [150], Loss: 0.8178
# Epoch [4], Batch [200], Loss: 0.8237
# Epoch [4], Batch [250], Loss: 0.8195
# Epoch [4], Batch [300], Loss: 0.8139
# Epoch [4], Batch [350], Loss: 0.8214
# Epoch [5], Batch [50], Loss: 0.7272
# Epoch [5], Batch [100], Loss: 0.7101
# Epoch [5], Batch [150], Loss: 0.7056
# Epoch [5], Batch [200], Loss: 0.7513
# Epoch [5], Batch [250], Loss: 0.7045
# Epoch [5], Batch [300], Loss: 0.7062
# Epoch [5], Batch [350], Loss: 0.6975
# Epoch [6], Batch [50], Loss: 0.6248
# Epoch [6], Batch [100], Loss: 0.6403
# Epoch [6], Batch [150], Loss: 0.6356
# Epoch [6], Batch [200], Loss: 0.6284
# Epoch [6], Batch [250], Loss: 0.6565
# Epoch [6], Batch [300], Loss: 0.6380
# Epoch [6], Batch [350], Loss: 0.6258
# Epoch [7], Batch [50], Loss: 0.5700
# Epoch [7], Batch [100], Loss: 0.5755
# Epoch [7], Batch [150], Loss: 0.5523
# Epoch [7], Batch [200], Loss: 0.5561
# Epoch [7], Batch [250], Loss: 0.5579
# Epoch [7], Batch [300], Loss: 0.5692
# Epoch [7], Batch [350], Loss: 0.5818
# Epoch [8], Batch [50], Loss: 0.4955
# Epoch [8], Batch [100], Loss: 0.4695
# Epoch [8], Batch [150], Loss: 0.5092
# Epoch [8], Batch [200], Loss: 0.5123
# Epoch [8], Batch [250], Loss: 0.4919
# Epoch [8], Batch [300], Loss: 0.5060
# Epoch [8], Batch [350], Loss: 0.5024
# Epoch [9], Batch [50], Loss: 0.4068
# Epoch [9], Batch [100], Loss: 0.4130
# Epoch [9], Batch [150], Loss: 0.4309
# Epoch [9], Batch [200], Loss: 0.4436
# Epoch [9], Batch [250], Loss: 0.4513
# Epoch [9], Batch [300], Loss: 0.4488
# Epoch [9], Batch [350], Loss: 0.4403
# Epoch [10], Batch [50], Loss: 0.3799
# Epoch [10], Batch [100], Loss: 0.3710
# Epoch [10], Batch [150], Loss: 0.3874
# Epoch [10], Batch [200], Loss: 0.3737
# Epoch [10], Batch [250], Loss: 0.3976
# Epoch [10], Batch [300], Loss: 0.4036
# Epoch [10], Batch [350], Loss: 0.3938
# [I 2025-04-30 19:43:31,412] Trial 19 finished with value: 77.79 and parameters: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.4870154347906195, 'num_fc_units': 512, 'learning_rate': 0.0005047891987218423, 'optimizer': 'Adam'}. Best is trial 13 with value: 79.03.
# Test Accuracy: 77.79%
# Number of finished trials: 20
# Best trial:
#   Value: 79.03
#   Params: {'num_conv_layers': 3, 'num_filters_base': 64, 'kernel_size': 3, 'dropout_rate': 0.42541390946706564, 'num_fc_units': 512, 'learning_rate': 0.0009755040618102396, 'optimizer': 'Adam'}
