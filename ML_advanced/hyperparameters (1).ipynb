# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 22.5 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 18.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
import optuna
import optuna.visualization as vis
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# --- Data Loading ---
def load_cifar10_data(batch_size=128):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

    testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
    testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader

# --- Model Definition ---
class SimpleCNN(nn.Module):
    def __init__(self, num_conv_layers, num_filters_base, kernel_size, dropout_rate, num_fc_units):
        super(SimpleCNN, self).__init__()
        self.conv_layers = nn.ModuleList()
        in_channels = 3
        for i in range(num_conv_layers):
            out_channels = num_filters_base * (2**i)
            self.conv_layers.append(nn.Conv2d(in_channels, out_channels, kernel_size, padding=kernel_size//2))
            self.conv_layers.append(nn.ReLU())
            self.conv_layers.append(nn.MaxPool2d(2, 2))
            in_channels = out_channels

        self.dropout = nn.Dropout(dropout_rate)

        with torch.no_grad():
            dummy_input = torch.randn(1, 3, 32, 32)
            for layer in self.conv_layers:
                dummy_input = layer(dummy_input)
            fc_input_size = torch.flatten(dummy_input, 1).shape[1]

        self.fc1 = nn.Linear(fc_input_size, num_fc_units)
        self.fc2 = nn.Linear(num_fc_units, 10)

    def forward(self, x):
        for layer in self.conv_layers:
            x = layer(x)
        x = torch.flatten(x, 1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

# --- Training and Evaluation ---
def train_model(model, train_loader, optimizer, criterion, num_epochs, device=None):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)
    all_losses = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        epoch_losses = []

        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            epoch_losses.append(loss.item())

            if i % 50 == 49:
                avg_loss = running_loss / 50
                print(f'Epoch [{epoch + 1}], Batch [{i + 1}], Loss: {avg_loss:.4f}')
                running_loss = 0.0

        avg_epoch_loss = np.mean(epoch_losses)
        all_losses.append(avg_epoch_loss)

    return all_losses

def evaluate_model(model, test_loader, device=None):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model.to(device)
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy:.2f}%')
    return accuracy

# --- Optuna Objective Function ---
def objective(trial):
    num_conv_layers = trial.suggest_int('num_conv_layers', 1, 3)
    num_filters_base = trial.suggest_categorical('num_filters_base', [16, 32, 64])
    kernel_size = trial.suggest_categorical('kernel_size', [3, 5])
    dropout_rate = trial.suggest_float('dropout_rate', 0.2, 0.6)
    num_fc_units = trial.suggest_categorical('num_fc_units', [128, 256, 512])
    learning_rate = trial.suggest_float('learning_rate', 5e-4, 5e-3, log=True)

    trainloader, testloader = load_cifar10_data()
    model = SimpleCNN(num_conv_layers, num_filters_base, kernel_size, dropout_rate, num_fc_units)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

    print(f'Starting trial {trial.number} with parameters: {trial.params}')
    epochs = 5
    losses = train_model(model, trainloader, optimizer, criterion, epochs)

    accuracy = evaluate_model(model, testloader)

    trial.set_user_attr("losses", losses)

    return accuracy

# --- Main Optimization Loop ---
if __name__ == '__main__':
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=10)

    print("Number of finished trials: {}".format(len(study.trials)))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: {}".format(trial.params))

    # --- Visualization of Loss ---
    plt.figure(figsize=(10, 6))
    for trial in study.trials:
        if trial.state == optuna.trial.TrialState.COMPLETE and "losses" in trial.user_attrs:
            epochs = range(1, len(trial.user_attrs["losses"]) + 1)
            plt.plot(epochs, trial.user_attrs["losses"], label=f'Trial {trial.number}')

    plt.title('Training Loss per Epoch for Different Trials')
    plt.xlabel('Epoch')
    plt.ylabel('Average Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    fig = vis.plot_param_importances(study)
    fig.update_layout(title='Важность гиперпараметров', width=800, height=500)
    fig.show()
# Out:
# [I 2025-05-16 12:58:52,432] A new study created in memory with name: no-name-99405810-426f-4733-8851-c23572fc5550
# Starting trial 0 with parameters: {'num_conv_layers': 1, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.42877167441833297, 'num_fc_units': 128, 'learning_rate': 0.0023677778950777937}
# Epoch [1], Batch [50], Loss: 2.1878
# Epoch [1], Batch [100], Loss: 1.9326
# Epoch [1], Batch [150], Loss: 1.8448
# Epoch [1], Batch [200], Loss: 1.8008
# Epoch [1], Batch [250], Loss: 1.7647
# Epoch [1], Batch [300], Loss: 1.7459
# Epoch [1], Batch [350], Loss: 1.7263
# Epoch [2], Batch [50], Loss: 1.6867
# Epoch [2], Batch [100], Loss: 1.6632
# Epoch [2], Batch [150], Loss: 1.6361
# Epoch [2], Batch [200], Loss: 1.6504
# Epoch [2], Batch [250], Loss: 1.6179
# Epoch [2], Batch [300], Loss: 1.6448
# Epoch [2], Batch [350], Loss: 1.6256
# Epoch [3], Batch [50], Loss: 1.5693
# Epoch [3], Batch [100], Loss: 1.5677
# Epoch [3], Batch [150], Loss: 1.5873
# Epoch [3], Batch [200], Loss: 1.5572
# Epoch [3], Batch [250], Loss: 1.5638
# Epoch [3], Batch [300], Loss: 1.5534
# Epoch [3], Batch [350], Loss: 1.5639
# Epoch [4], Batch [50], Loss: 1.5251
# Epoch [4], Batch [100], Loss: 1.5161
# Epoch [4], Batch [150], Loss: 1.5078
# Epoch [4], Batch [200], Loss: 1.5338
# Epoch [4], Batch [250], Loss: 1.5319
# Epoch [4], Batch [300], Loss: 1.5296
# Epoch [4], Batch [350], Loss: 1.5493
# Epoch [5], Batch [50], Loss: 1.4836
# Epoch [5], Batch [100], Loss: 1.4961
# Epoch [5], Batch [150], Loss: 1.4938
# Epoch [5], Batch [200], Loss: 1.5210
# Epoch [5], Batch [250], Loss: 1.5008
# Epoch [5], Batch [300], Loss: 1.4963
# Epoch [5], Batch [350], Loss: 1.4790
# [I 2025-05-16 12:59:57,108] Trial 0 finished with value: 64.76 and parameters: {'num_conv_layers': 1, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.42877167441833297, 'num_fc_units': 128, 'learning_rate': 0.0023677778950777937}. Best is trial 0 with value: 64.76.
# Test Accuracy: 64.76%
# Starting trial 1 with parameters: {'num_conv_layers': 2, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.5237666704005612, 'num_fc_units': 128, 'learning_rate': 0.0028922496134671533}
# Epoch [1], Batch [50], Loss: 2.0864
# Epoch [1], Batch [100], Loss: 1.8672
# Epoch [1], Batch [150], Loss: 1.8197
# Epoch [1], Batch [200], Loss: 1.7269
# Epoch [1], Batch [250], Loss: 1.6825
# Epoch [1], Batch [300], Loss: 1.6855
# Epoch [1], Batch [350], Loss: 1.6475
# Epoch [2], Batch [50], Loss: 1.5930
# Epoch [2], Batch [100], Loss: 1.5877
# Epoch [2], Batch [150], Loss: 1.5816
# Epoch [2], Batch [200], Loss: 1.5465
# Epoch [2], Batch [250], Loss: 1.5514
# Epoch [2], Batch [300], Loss: 1.5194
# Epoch [2], Batch [350], Loss: 1.5192
# Epoch [3], Batch [50], Loss: 1.4664
# Epoch [3], Batch [100], Loss: 1.4829
# Epoch [3], Batch [150], Loss: 1.4794
# Epoch [3], Batch [200], Loss: 1.4765
# Epoch [3], Batch [250], Loss: 1.4670
# Epoch [3], Batch [300], Loss: 1.4882
# Epoch [3], Batch [350], Loss: 1.4448
# Epoch [4], Batch [50], Loss: 1.4446
# Epoch [4], Batch [100], Loss: 1.4159
# Epoch [4], Batch [150], Loss: 1.4240
# Epoch [4], Batch [200], Loss: 1.4270
# Epoch [4], Batch [250], Loss: 1.4347
# Epoch [4], Batch [300], Loss: 1.4117
# Epoch [4], Batch [350], Loss: 1.4196
# Epoch [5], Batch [50], Loss: 1.3856
# Epoch [5], Batch [100], Loss: 1.3955
# Epoch [5], Batch [150], Loss: 1.3881
# Epoch [5], Batch [200], Loss: 1.3909
# Epoch [5], Batch [250], Loss: 1.3791
# Epoch [5], Batch [300], Loss: 1.4193
# Epoch [5], Batch [350], Loss: 1.3798
# [I 2025-05-16 13:01:01,590] Trial 1 finished with value: 64.39 and parameters: {'num_conv_layers': 2, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.5237666704005612, 'num_fc_units': 128, 'learning_rate': 0.0028922496134671533}. Best is trial 0 with value: 64.76.
# Test Accuracy: 64.39%
# Starting trial 2 with parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.31221374239103533, 'num_fc_units': 128, 'learning_rate': 0.003300381358051769}
# Epoch [1], Batch [50], Loss: 2.1189
# Epoch [1], Batch [100], Loss: 1.8934
# Epoch [1], Batch [150], Loss: 1.8185
# Epoch [1], Batch [200], Loss: 1.7582
# Epoch [1], Batch [250], Loss: 1.7029
# Epoch [1], Batch [300], Loss: 1.6616
# Epoch [1], Batch [350], Loss: 1.6318
# Epoch [2], Batch [50], Loss: 1.5691
# Epoch [2], Batch [100], Loss: 1.5658
# Epoch [2], Batch [150], Loss: 1.5343
# Epoch [2], Batch [200], Loss: 1.4952
# Epoch [2], Batch [250], Loss: 1.4945
# Epoch [2], Batch [300], Loss: 1.4640
# Epoch [2], Batch [350], Loss: 1.4634
# Epoch [3], Batch [50], Loss: 1.4006
# Epoch [3], Batch [100], Loss: 1.3974
# Epoch [3], Batch [150], Loss: 1.3982
# Epoch [3], Batch [200], Loss: 1.3761
# Epoch [3], Batch [250], Loss: 1.3691
# Epoch [3], Batch [300], Loss: 1.3793
# Epoch [3], Batch [350], Loss: 1.3464
# Epoch [4], Batch [50], Loss: 1.3035
# Epoch [4], Batch [100], Loss: 1.3050
# Epoch [4], Batch [150], Loss: 1.3341
# Epoch [4], Batch [200], Loss: 1.3149
# Epoch [4], Batch [250], Loss: 1.3266
# Epoch [4], Batch [300], Loss: 1.3135
# Epoch [4], Batch [350], Loss: 1.3086
# Epoch [5], Batch [50], Loss: 1.2663
# Epoch [5], Batch [100], Loss: 1.2527
# Epoch [5], Batch [150], Loss: 1.2599
# Epoch [5], Batch [200], Loss: 1.2516
# Epoch [5], Batch [250], Loss: 1.2638
# Epoch [5], Batch [300], Loss: 1.2745
# Epoch [5], Batch [350], Loss: 1.2566
# [I 2025-05-16 13:02:08,033] Trial 2 finished with value: 66.92 and parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 5, 'dropout_rate': 0.31221374239103533, 'num_fc_units': 128, 'learning_rate': 0.003300381358051769}. Best is trial 2 with value: 66.92.
# Test Accuracy: 66.92%
# Starting trial 3 with parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5233734083899338, 'num_fc_units': 256, 'learning_rate': 0.0028540264505858897}
# Epoch [1], Batch [50], Loss: 2.1441
# Epoch [1], Batch [100], Loss: 1.8902
# Epoch [1], Batch [150], Loss: 1.7420
# Epoch [1], Batch [200], Loss: 1.6555
# Epoch [1], Batch [250], Loss: 1.6117
# Epoch [1], Batch [300], Loss: 1.5740
# Epoch [1], Batch [350], Loss: 1.5300
# Epoch [2], Batch [50], Loss: 1.4787
# Epoch [2], Batch [100], Loss: 1.4536
# Epoch [2], Batch [150], Loss: 1.4198
# Epoch [2], Batch [200], Loss: 1.4047
# Epoch [2], Batch [250], Loss: 1.4121
# Epoch [2], Batch [300], Loss: 1.4067
# Epoch [2], Batch [350], Loss: 1.3767
# Epoch [3], Batch [50], Loss: 1.3210
# Epoch [3], Batch [100], Loss: 1.3220
# Epoch [3], Batch [150], Loss: 1.3308
# Epoch [3], Batch [200], Loss: 1.3288
# Epoch [3], Batch [250], Loss: 1.3087
# Epoch [3], Batch [300], Loss: 1.2948
# Epoch [3], Batch [350], Loss: 1.2993
# Epoch [4], Batch [50], Loss: 1.2626
# Epoch [4], Batch [100], Loss: 1.2659
# Epoch [4], Batch [150], Loss: 1.2438
# Epoch [4], Batch [200], Loss: 1.2442
# Epoch [4], Batch [250], Loss: 1.2610
# Epoch [4], Batch [300], Loss: 1.2295
# Epoch [4], Batch [350], Loss: 1.2279
# Epoch [5], Batch [50], Loss: 1.1899
# Epoch [5], Batch [100], Loss: 1.1930
# Epoch [5], Batch [150], Loss: 1.2062
# Epoch [5], Batch [200], Loss: 1.1941
# Epoch [5], Batch [250], Loss: 1.2187
# Epoch [5], Batch [300], Loss: 1.1855
# Epoch [5], Batch [350], Loss: 1.2005
# [I 2025-05-16 13:03:12,251] Trial 3 finished with value: 71.71 and parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5233734083899338, 'num_fc_units': 256, 'learning_rate': 0.0028540264505858897}. Best is trial 3 with value: 71.71.
# Test Accuracy: 71.71%
# Starting trial 4 with parameters: {'num_conv_layers': 1, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.4954125273758395, 'num_fc_units': 512, 'learning_rate': 0.003246182771076079}
# Epoch [1], Batch [50], Loss: 2.6131
# Epoch [1], Batch [100], Loss: 1.9849
# Epoch [1], Batch [150], Loss: 1.8804
# Epoch [1], Batch [200], Loss: 1.8267
# Epoch [1], Batch [250], Loss: 1.8008
# Epoch [1], Batch [300], Loss: 1.7758
# Epoch [1], Batch [350], Loss: 1.7622
# Epoch [2], Batch [50], Loss: 1.7210
# Epoch [2], Batch [100], Loss: 1.7146
# Epoch [2], Batch [150], Loss: 1.7082
# Epoch [2], Batch [200], Loss: 1.6857
# Epoch [2], Batch [250], Loss: 1.6552
# Epoch [2], Batch [300], Loss: 1.6852
# Epoch [2], Batch [350], Loss: 1.6517
# Epoch [3], Batch [50], Loss: 1.6426
# Epoch [3], Batch [100], Loss: 1.6220
# Epoch [3], Batch [150], Loss: 1.6166
# Epoch [3], Batch [200], Loss: 1.6046
# Epoch [3], Batch [250], Loss: 1.6263
# Epoch [3], Batch [300], Loss: 1.5980
# Epoch [3], Batch [350], Loss: 1.6153
# Epoch [4], Batch [50], Loss: 1.5894
# Epoch [4], Batch [100], Loss: 1.5993
# Epoch [4], Batch [150], Loss: 1.5723
# Epoch [4], Batch [200], Loss: 1.5597
# Epoch [4], Batch [250], Loss: 1.5977
# Epoch [4], Batch [300], Loss: 1.5897
# Epoch [4], Batch [350], Loss: 1.5641
# Epoch [5], Batch [50], Loss: 1.5435
# Epoch [5], Batch [100], Loss: 1.5523
# Epoch [5], Batch [150], Loss: 1.5501
# Epoch [5], Batch [200], Loss: 1.5584
# Epoch [5], Batch [250], Loss: 1.5615
# Epoch [5], Batch [300], Loss: 1.5512
# Epoch [5], Batch [350], Loss: 1.5590
# [I 2025-05-16 13:04:19,210] Trial 4 finished with value: 62.15 and parameters: {'num_conv_layers': 1, 'num_filters_base': 64, 'kernel_size': 5, 'dropout_rate': 0.4954125273758395, 'num_fc_units': 512, 'learning_rate': 0.003246182771076079}. Best is trial 3 with value: 71.71.
# Test Accuracy: 62.15%
# Starting trial 5 with parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.528409743280793, 'num_fc_units': 256, 'learning_rate': 0.00378433716568753}
# Epoch [1], Batch [50], Loss: 2.4557
# Epoch [1], Batch [100], Loss: 2.0485
# Epoch [1], Batch [150], Loss: 1.9618
# Epoch [1], Batch [200], Loss: 1.9367
# Epoch [1], Batch [250], Loss: 1.8851
# Epoch [1], Batch [300], Loss: 1.8710
# Epoch [1], Batch [350], Loss: 1.8651
# Epoch [2], Batch [50], Loss: 1.8424
# Epoch [2], Batch [100], Loss: 1.8091
# Epoch [2], Batch [150], Loss: 1.8076
# Epoch [2], Batch [200], Loss: 1.7799
# Epoch [2], Batch [250], Loss: 1.8110
# Epoch [2], Batch [300], Loss: 1.7821
# Epoch [2], Batch [350], Loss: 1.7884
# Epoch [3], Batch [50], Loss: 1.7628
# Epoch [3], Batch [100], Loss: 1.7614
# Epoch [3], Batch [150], Loss: 1.7541
# Epoch [3], Batch [200], Loss: 1.7435
# Epoch [3], Batch [250], Loss: 1.7440
# Epoch [3], Batch [300], Loss: 1.7507
# Epoch [3], Batch [350], Loss: 1.7542
# Epoch [4], Batch [50], Loss: 1.7169
# Epoch [4], Batch [100], Loss: 1.7041
# Epoch [4], Batch [150], Loss: 1.7256
# Epoch [4], Batch [200], Loss: 1.7148
# Epoch [4], Batch [250], Loss: 1.7174
# Epoch [4], Batch [300], Loss: 1.7167
# Epoch [4], Batch [350], Loss: 1.7357
# Epoch [5], Batch [50], Loss: 1.7020
# Epoch [5], Batch [100], Loss: 1.7186
# Epoch [5], Batch [150], Loss: 1.7026
# Epoch [5], Batch [200], Loss: 1.6916
# Epoch [5], Batch [250], Loss: 1.7011
# Epoch [5], Batch [300], Loss: 1.6857
# Epoch [5], Batch [350], Loss: 1.6930
# [I 2025-05-16 13:05:21,919] Trial 5 finished with value: 58.74 and parameters: {'num_conv_layers': 1, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.528409743280793, 'num_fc_units': 256, 'learning_rate': 0.00378433716568753}. Best is trial 3 with value: 71.71.
# Test Accuracy: 58.74%
# Starting trial 6 with parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.24210728586338895, 'num_fc_units': 512, 'learning_rate': 0.0011800249320304428}
# Epoch [1], Batch [50], Loss: 2.0559
# Epoch [1], Batch [100], Loss: 1.8266
# Epoch [1], Batch [150], Loss: 1.7149
# Epoch [1], Batch [200], Loss: 1.6803
# Epoch [1], Batch [250], Loss: 1.5956
# Epoch [1], Batch [300], Loss: 1.5553
# Epoch [1], Batch [350], Loss: 1.5477
# Epoch [2], Batch [50], Loss: 1.4592
# Epoch [2], Batch [100], Loss: 1.4513
# Epoch [2], Batch [150], Loss: 1.4175
# Epoch [2], Batch [200], Loss: 1.3989
# Epoch [2], Batch [250], Loss: 1.3716
# Epoch [2], Batch [300], Loss: 1.3640
# Epoch [2], Batch [350], Loss: 1.3382
# Epoch [3], Batch [50], Loss: 1.2942
# Epoch [3], Batch [100], Loss: 1.2760
# Epoch [3], Batch [150], Loss: 1.2576
# Epoch [3], Batch [200], Loss: 1.2434
# Epoch [3], Batch [250], Loss: 1.2679
# Epoch [3], Batch [300], Loss: 1.2345
# Epoch [3], Batch [350], Loss: 1.2609
# Epoch [4], Batch [50], Loss: 1.1878
# Epoch [4], Batch [100], Loss: 1.1848
# Epoch [4], Batch [150], Loss: 1.1859
# Epoch [4], Batch [200], Loss: 1.1815
# Epoch [4], Batch [250], Loss: 1.1713
# Epoch [4], Batch [300], Loss: 1.1792
# Epoch [4], Batch [350], Loss: 1.1665
# Epoch [5], Batch [50], Loss: 1.1157
# Epoch [5], Batch [100], Loss: 1.1213
# Epoch [5], Batch [150], Loss: 1.1275
# Epoch [5], Batch [200], Loss: 1.1212
# Epoch [5], Batch [250], Loss: 1.1240
# Epoch [5], Batch [300], Loss: 1.1224
# Epoch [5], Batch [350], Loss: 1.1092
# [I 2025-05-16 13:06:26,124] Trial 6 finished with value: 71.7 and parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.24210728586338895, 'num_fc_units': 512, 'learning_rate': 0.0011800249320304428}. Best is trial 3 with value: 71.71.
# Test Accuracy: 71.70%
# Starting trial 7 with parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.4030450810227455, 'num_fc_units': 512, 'learning_rate': 0.0023909185356026}
# Epoch [1], Batch [50], Loss: 2.0402
# Epoch [1], Batch [100], Loss: 1.7981
# Epoch [1], Batch [150], Loss: 1.7223
# Epoch [1], Batch [200], Loss: 1.6454
# Epoch [1], Batch [250], Loss: 1.5737
# Epoch [1], Batch [300], Loss: 1.5494
# Epoch [1], Batch [350], Loss: 1.5024
# Epoch [2], Batch [50], Loss: 1.4246
# Epoch [2], Batch [100], Loss: 1.4388
# Epoch [2], Batch [150], Loss: 1.3787
# Epoch [2], Batch [200], Loss: 1.3529
# Epoch [2], Batch [250], Loss: 1.3628
# Epoch [2], Batch [300], Loss: 1.3506
# Epoch [2], Batch [350], Loss: 1.3293
# Epoch [3], Batch [50], Loss: 1.2595
# Epoch [3], Batch [100], Loss: 1.2247
# Epoch [3], Batch [150], Loss: 1.2559
# Epoch [3], Batch [200], Loss: 1.2723
# Epoch [3], Batch [250], Loss: 1.2713
# Epoch [3], Batch [300], Loss: 1.2401
# Epoch [3], Batch [350], Loss: 1.2489
# Epoch [4], Batch [50], Loss: 1.1778
# Epoch [4], Batch [100], Loss: 1.1667
# Epoch [4], Batch [150], Loss: 1.1649
# Epoch [4], Batch [200], Loss: 1.1975
# Epoch [4], Batch [250], Loss: 1.1731
# Epoch [4], Batch [300], Loss: 1.1902
# Epoch [4], Batch [350], Loss: 1.1562
# Epoch [5], Batch [50], Loss: 1.0928
# Epoch [5], Batch [100], Loss: 1.1140
# Epoch [5], Batch [150], Loss: 1.1242
# Epoch [5], Batch [200], Loss: 1.1529
# Epoch [5], Batch [250], Loss: 1.1305
# Epoch [5], Batch [300], Loss: 1.1256
# Epoch [5], Batch [350], Loss: 1.1309
# [I 2025-05-16 13:07:31,391] Trial 7 finished with value: 70.86 and parameters: {'num_conv_layers': 3, 'num_filters_base': 16, 'kernel_size': 5, 'dropout_rate': 0.4030450810227455, 'num_fc_units': 512, 'learning_rate': 0.0023909185356026}. Best is trial 3 with value: 71.71.
# Test Accuracy: 70.86%
# Starting trial 8 with parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5914833093854992, 'num_fc_units': 512, 'learning_rate': 0.0014659937642408838}
# Epoch [1], Batch [50], Loss: 2.0446
# Epoch [1], Batch [100], Loss: 1.8174
# Epoch [1], Batch [150], Loss: 1.7370
# Epoch [1], Batch [200], Loss: 1.7016
# Epoch [1], Batch [250], Loss: 1.6645
# Epoch [1], Batch [300], Loss: 1.6246
# Epoch [1], Batch [350], Loss: 1.6061
# Epoch [2], Batch [50], Loss: 1.5479
# Epoch [2], Batch [100], Loss: 1.5450
# Epoch [2], Batch [150], Loss: 1.5460
# Epoch [2], Batch [200], Loss: 1.5461
# Epoch [2], Batch [250], Loss: 1.5103
# Epoch [2], Batch [300], Loss: 1.5151
# Epoch [2], Batch [350], Loss: 1.5064
# Epoch [3], Batch [50], Loss: 1.4616
# Epoch [3], Batch [100], Loss: 1.4564
# Epoch [3], Batch [150], Loss: 1.4639
# Epoch [3], Batch [200], Loss: 1.4636
# Epoch [3], Batch [250], Loss: 1.4599
# Epoch [3], Batch [300], Loss: 1.4490
# Epoch [3], Batch [350], Loss: 1.4433
# Epoch [4], Batch [50], Loss: 1.4105
# Epoch [4], Batch [100], Loss: 1.4139
# Epoch [4], Batch [150], Loss: 1.4172
# Epoch [4], Batch [200], Loss: 1.4143
# Epoch [4], Batch [250], Loss: 1.4220
# Epoch [4], Batch [300], Loss: 1.3981
# Epoch [4], Batch [350], Loss: 1.3932
# Epoch [5], Batch [50], Loss: 1.3674
# Epoch [5], Batch [100], Loss: 1.3515
# Epoch [5], Batch [150], Loss: 1.3814
# Epoch [5], Batch [200], Loss: 1.3757
# Epoch [5], Batch [250], Loss: 1.3566
# Epoch [5], Batch [300], Loss: 1.3972
# Epoch [5], Batch [350], Loss: 1.3764
# [I 2025-05-16 13:08:32,916] Trial 8 finished with value: 63.66 and parameters: {'num_conv_layers': 1, 'num_filters_base': 16, 'kernel_size': 3, 'dropout_rate': 0.5914833093854992, 'num_fc_units': 512, 'learning_rate': 0.0014659937642408838}. Best is trial 3 with value: 71.71.
# Test Accuracy: 63.66%
# Starting trial 9 with parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5763324611606188, 'num_fc_units': 512, 'learning_rate': 0.0044392630863421476}
# Epoch [1], Batch [50], Loss: 2.2122
# Epoch [1], Batch [100], Loss: 2.0221
# Epoch [1], Batch [150], Loss: 1.8883
# Epoch [1], Batch [200], Loss: 1.8048
# Epoch [1], Batch [250], Loss: 1.7570
# Epoch [1], Batch [300], Loss: 1.7459
# Epoch [1], Batch [350], Loss: 1.7213
# Epoch [2], Batch [50], Loss: 1.6517
# Epoch [2], Batch [100], Loss: 1.6587
# Epoch [2], Batch [150], Loss: 1.6412
# Epoch [2], Batch [200], Loss: 1.6459
# Epoch [2], Batch [250], Loss: 1.6013
# Epoch [2], Batch [300], Loss: 1.6009
# Epoch [2], Batch [350], Loss: 1.5805
# Epoch [3], Batch [50], Loss: 1.5535
# Epoch [3], Batch [100], Loss: 1.5408
# Epoch [3], Batch [150], Loss: 1.5340
# Epoch [3], Batch [200], Loss: 1.5539
# Epoch [3], Batch [250], Loss: 1.5508
# Epoch [3], Batch [300], Loss: 1.5280
# Epoch [3], Batch [350], Loss: 1.5274
# Epoch [4], Batch [50], Loss: 1.5135
# Epoch [4], Batch [100], Loss: 1.4936
# Epoch [4], Batch [150], Loss: 1.4836
# Epoch [4], Batch [200], Loss: 1.4929
# Epoch [4], Batch [250], Loss: 1.5081
# Epoch [4], Batch [300], Loss: 1.4849
# Epoch [4], Batch [350], Loss: 1.4945
# Epoch [5], Batch [50], Loss: 1.4622
# Epoch [5], Batch [100], Loss: 1.4618
# Epoch [5], Batch [150], Loss: 1.4741
# Epoch [5], Batch [200], Loss: 1.4799
# Epoch [5], Batch [250], Loss: 1.4684
# Epoch [5], Batch [300], Loss: 1.4786
# Epoch [5], Batch [350], Loss: 1.4619
# [I 2025-05-16 13:09:37,630] Trial 9 finished with value: 60.61 and parameters: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5763324611606188, 'num_fc_units': 512, 'learning_rate': 0.0044392630863421476}. Best is trial 3 with value: 71.71.
# Test Accuracy: 60.61%
# Number of finished trials: 10
# Best trial:
#   Value: 71.71
#   Params: {'num_conv_layers': 3, 'num_filters_base': 32, 'kernel_size': 3, 'dropout_rate': 0.5233734083899338, 'num_fc_units': 256, 'learning_rate': 0.0028540264505858897}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="38003592-60ac-470c-9bcc-e07f26c9ebbe" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38003592-60ac-470c-9bcc-e07f26c9ebbe")) {                    Plotly.newPlot(                        "38003592-60ac-470c-9bcc-e07f26c9ebbe",                        [{"cliponaxis":false,"hovertemplate":["kernel_size (CategoricalDistribution): 0.053444261294460234\u003cextra\u003e\u003c\u002fextra\u003e","num_filters_base (CategoricalDistribution): 0.06233399704120924\u003cextra\u003e\u003c\u002fextra\u003e","num_fc_units (CategoricalDistribution): 0.1198805611290071\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 0.1953177567111977\u003cextra\u003e\u003c\u002fextra\u003e","num_conv_layers (IntDistribution): 0.25724320069523643\u003cextra\u003e\u003c\u002fextra\u003e","dropout_rate (FloatDistribution): 0.3117802231288893\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["0.05","0.06","0.12","0.20","0.26","0.31"],"textposition":"outside","x":[0.053444261294460234,0.06233399704120924,0.1198805611290071,0.1953177567111977,0.25724320069523643,0.3117802231288893],"y":["kernel_size","num_filters_base","num_fc_units","learning_rate","num_conv_layers","dropout_rate"],"type":"bar"}],                        {"title":{"text":"Важность гиперпараметров"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd378 ...
